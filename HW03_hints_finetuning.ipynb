# %% [markdown]
# # HW03 Fine-tuning

# %% [markdown]
# I recommend to work in [Lightning studio](https://lightning.ai/simecek/studios/fastai-transfer-learning-fine-tuning~01hv3p406bs3pebc3xm2qwtwz1) (and not Colab), because of preinstalled environment and permanent disk space.
#
# ## Data preparation
#
#  1. You need to upload your dataset to the virtual machine. Since the dataset is relatively small, it's easiest to ZIP the data and use the 'Upload Files' button in the top left corner.
#  2. You can unzip the data either through the Terminal or directly within the Jupyter Notebook using the command: `!unzip YOURFILENAME.zip`
#  3. Optionally, organize the image files as shown in the schema below.
#
# ```
# DATASET_NAME/
# │
# ├── train/
# │   ├── CATEGORY1/
# │   │   ├── image1.jpg
# │   │   ├── image2.jpg
# │   │   └── ...
# │   ├── CATEGORY2/
# │   │   ├── image1.jpg
# │   │   ├── image2.jpg
# │   │   └── ...
# │   └── ...
# │
# └── test/
#     ├── CATEGORY1/
#     │   ├── image1.jpg
#     │   ├── image2.jpg
#     │   └── ...
#     ├── CATEGORY2/
#     │   ├── image1.jpg
#     │   ├── image2.jpg
#     │   └── ...
#     └── ...
# ```
#
# If the data are organized in this form, you can obtain dataloaders as below. Otherwise, adapt `ImageDataLoaders` / `DataBlocks` accordingly.

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#    creating: dataset/airplanes/
#   inflating: dataset/.DS_Store
#   inflating: __MACOSX/dataset/._.DS_Store
#    creating: dataset/motorboat/
#    creating: dataset/motorcycles/
#    creating: dataset/cars/
#    creating: dataset/trains/
#   inflating: dataset/airplanes/airplane234.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane234.jpg
#   inflating: dataset/airplanes/airplane220.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane220.jpg
#   inflating: dataset/airplanes/airplane9.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane9.jpg
#   inflating: dataset/airplanes/airplane156.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane156.jpg
#   inflating: dataset/airplanes/airplane80.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane80.jpg
#   inflating: dataset/airplanes/airplane43.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane43.jpg
#   inflating: dataset/airplanes/airplane432.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane432.jpg
#   inflating: dataset/airplanes/airplane397.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane397.jpg
#   inflating: dataset/airplanes/airplane369.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane369.jpg
#   inflating: dataset/airplanes/airplane433.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane433.jpg
#   inflating: dataset/airplanes/airplane56.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane56.jpg
#   inflating: dataset/airplanes/airplane194.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane194.jpg
#   inflating: dataset/airplanes/airplane180.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane180.jpg
#   inflating: dataset/airplanes/airplane81.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane81.jpg
#   inflating: dataset/airplanes/airplane209.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane209.jpg
#   inflating: dataset/airplanes/airplane97.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane97.jpg
#   inflating: dataset/airplanes/airplane169.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane169.jpg
#   inflating: dataset/airplanes/airplane83.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane83.jpg
#   inflating: dataset/airplanes/airplane54.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane54.jpg
#   inflating: dataset/airplanes/airplane357.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane357.jpg
#   inflating: dataset/airplanes/airplane419.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane419.jpg
#   inflating: dataset/airplanes/airplane380.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane380.jpg
#   inflating: dataset/airplanes/airplane430.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane430.jpg
#   inflating: dataset/airplanes/airplane41.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane41.jpg
#   inflating: dataset/airplanes/airplane55.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane55.jpg
#   inflating: dataset/airplanes/airplane69.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane69.jpg
#   inflating: dataset/airplanes/airplane154.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane154.jpg
#   inflating: dataset/airplanes/airplane144.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane144.jpg
#   inflating: dataset/airplanes/airplane51.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane51.jpg
#   inflating: dataset/airplanes/airplane187.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane187.jpg
#   inflating: dataset/airplanes/airplane79.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane79.jpg
#   inflating: dataset/airplanes/.DS_Store
#   inflating: __MACOSX/dataset/airplanes/._.DS_Store
#   inflating: dataset/airplanes/airplane420.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane420.jpg
#   inflating: dataset/airplanes/airplane391.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane391.jpg
#   inflating: dataset/airplanes/airplane384.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane384.jpg
#   inflating: dataset/airplanes/airplane390.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane390.jpg
#   inflating: dataset/airplanes/airplane435.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane435.jpg
#   inflating: dataset/airplanes/airplane409.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane409.jpg
#   inflating: dataset/airplanes/airplane78.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane78.jpg
#   inflating: dataset/airplanes/airplane186.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane186.jpg
#   inflating: dataset/airplanes/airplane50.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane50.jpg
#   inflating: dataset/airplanes/airplane151.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane151.jpg
#   inflating: dataset/airplanes/airplane87.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane87.jpg
#   inflating: dataset/airplanes/airplane93.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane93.jpg
#   inflating: dataset/airplanes/airplane219.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane219.jpg
#   inflating: dataset/airplanes/airplane46.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane46.jpg
#   inflating: dataset/airplanes/airplane190.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane190.jpg
#   inflating: dataset/airplanes/airplane423.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane423.jpg
#   inflating: dataset/airplanes/airplane351.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane351.jpg
#   inflating: dataset/airplanes/airplane386.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane386.jpg
#   inflating: dataset/airplanes/airplane378.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane378.jpg
#   inflating: dataset/airplanes/airplane191.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane191.jpg
#   inflating: dataset/airplanes/airplane47.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane47.jpg
#   inflating: dataset/airplanes/airplane152.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane152.jpg
#   inflating: dataset/airplanes/airplane146.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane146.jpg
#   inflating: dataset/airplanes/airplane257.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane257.jpg
#   inflating: dataset/airplanes/airplane121.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane121.jpg
#   inflating: dataset/airplanes/airplane135.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane135.jpg
#   inflating: dataset/airplanes/airplane109.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane109.jpg
#   inflating: dataset/airplanes/airplane323.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane323.jpg
#   inflating: dataset/airplanes/airplane445.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane445.jpg
#   inflating: dataset/airplanes/airplane451.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane451.jpg
#   inflating: dataset/airplanes/airplane337.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane337.jpg
#   inflating: dataset/airplanes/airplane322.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane322.jpg
#   inflating: dataset/airplanes/airplane134.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane134.jpg
#   inflating: dataset/airplanes/airplane120.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane120.jpg
#   inflating: dataset/airplanes/airplane281.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane281.jpg
#   inflating: dataset/airplanes/airplane295.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane295.jpg
#   inflating: dataset/airplanes/airplane242.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane242.jpg
#   inflating: dataset/airplanes/airplane268.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane268.jpg
#   inflating: dataset/airplanes/airplane37.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane37.jpg
#   inflating: dataset/airplanes/airplane23.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane23.jpg
#   inflating: dataset/airplanes/airplane334.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane334.jpg
#   inflating: dataset/airplanes/airplane320.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane320.jpg
#   inflating: dataset/airplanes/airplane447.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane447.jpg
#   inflating: dataset/airplanes/airplane335.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane335.jpg
#   inflating: dataset/airplanes/airplane137.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane137.jpg
#   inflating: dataset/airplanes/airplane269.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane269.jpg
#   inflating: dataset/airplanes/airplane255.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane255.jpg
#   inflating: dataset/airplanes/airplane245.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane245.jpg
#   inflating: dataset/airplanes/airplane251.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane251.jpg
#   inflating: dataset/airplanes/airplane286.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane286.jpg
#   inflating: dataset/airplanes/airplane292.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane292.jpg
#   inflating: dataset/airplanes/airplane127.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane127.jpg
#   inflating: dataset/airplanes/airplane32.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane32.jpg
#   inflating: dataset/airplanes/airplane26.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane26.jpg
#   inflating: dataset/airplanes/airplane443.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane443.jpg
#   inflating: dataset/airplanes/airplane324.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane324.jpg
#   inflating: dataset/airplanes/airplane318.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane318.jpg
#   inflating: dataset/airplanes/airplane27.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane27.jpg
#   inflating: dataset/airplanes/airplane33.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane33.jpg
#   inflating: dataset/airplanes/airplane293.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane293.jpg
#   inflating: dataset/airplanes/airplane291.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane291.jpg
#   inflating: dataset/airplanes/airplane124.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane124.jpg
#   inflating: dataset/airplanes/airplane130.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane130.jpg
#   inflating: dataset/airplanes/airplane31.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane31.jpg
#   inflating: dataset/airplanes/airplane19.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane19.jpg
#   inflating: dataset/airplanes/airplane440.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane440.jpg
#   inflating: dataset/airplanes/airplane326.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane326.jpg
#   inflating: dataset/airplanes/airplane332.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane332.jpg
#   inflating: dataset/airplanes/airplane441.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane441.jpg
#   inflating: dataset/airplanes/airplane30.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane30.jpg
#   inflating: dataset/airplanes/airplane131.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane131.jpg
#   inflating: dataset/airplanes/airplane284.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane284.jpg
#   inflating: dataset/airplanes/airplane290.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane290.jpg
#   inflating: dataset/airplanes/airplane247.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane247.jpg
#   inflating: dataset/airplanes/airplane253.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane253.jpg
#   inflating: dataset/airplanes/airplane276.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane276.jpg
#   inflating: dataset/airplanes/airplane262.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane262.jpg
#   inflating: dataset/airplanes/airplane289.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane289.jpg
#   inflating: dataset/airplanes/airplane114.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane114.jpg
#   inflating: dataset/airplanes/airplane303.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane303.jpg
#   inflating: dataset/airplanes/airplane14.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane14.jpg
#   inflating: dataset/airplanes/airplane28.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane28.jpg
#   inflating: dataset/airplanes/airplane115.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane115.jpg
#   inflating: dataset/airplanes/airplane101.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane101.jpg
#   inflating: dataset/airplanes/airplane261.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane261.jpg
#   inflating: dataset/airplanes/airplane249.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane249.jpg
#   inflating: dataset/airplanes/airplane117.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane117.jpg
#   inflating: dataset/airplanes/airplane315.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane315.jpg
#   inflating: dataset/airplanes/airplane301.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane301.jpg
#   inflating: dataset/airplanes/airplane314.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane314.jpg
#   inflating: dataset/airplanes/airplane116.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane116.jpg
#   inflating: dataset/airplanes/airplane260.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane260.jpg
#   inflating: dataset/airplanes/airplane264.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane264.jpg
#   inflating: dataset/airplanes/airplane112.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane112.jpg
#   inflating: dataset/airplanes/airplane338.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane338.jpg
#   inflating: dataset/airplanes/airplane304.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane304.jpg
#   inflating: dataset/airplanes/airplane311.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane311.jpg
#   inflating: dataset/airplanes/airplane339.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane339.jpg
#   inflating: dataset/airplanes/airplane107.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane107.jpg
#   inflating: dataset/airplanes/airplane271.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane271.jpg
#   inflating: dataset/airplanes/airplane265.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane265.jpg
#   inflating: dataset/airplanes/airplane267.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane267.jpg
#   inflating: dataset/airplanes/airplane105.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane105.jpg
#   inflating: dataset/airplanes/airplane449.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane449.jpg
#   inflating: dataset/airplanes/airplane312.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane312.jpg
#   inflating: dataset/airplanes/airplane306.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane306.jpg
#   inflating: dataset/airplanes/airplane448.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane448.jpg
#   inflating: dataset/airplanes/airplane11.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane11.jpg
#   inflating: dataset/airplanes/airplane110.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane110.jpg
#   inflating: dataset/airplanes/airplane272.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane272.jpg
#   inflating: dataset/airplanes/airplane201.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane201.jpg
#   inflating: dataset/airplanes/airplane163.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane163.jpg
#   inflating: dataset/airplanes/airplane89.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane89.jpg
#   inflating: dataset/airplanes/airplane177.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane177.jpg
#   inflating: dataset/airplanes/airplane361.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane361.jpg
#   inflating: dataset/airplanes/airplane375.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane375.jpg
#   inflating: dataset/airplanes/airplane349.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane349.jpg
#   inflating: dataset/airplanes/airplane348.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane348.jpg
#   inflating: dataset/airplanes/airplane374.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane374.jpg
#   inflating: dataset/airplanes/airplane360.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane360.jpg
#   inflating: dataset/airplanes/airplane77.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane77.jpg
#   inflating: dataset/airplanes/airplane176.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane176.jpg
#   inflating: dataset/airplanes/airplane88.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane88.jpg
#   inflating: dataset/airplanes/airplane1.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane1.jpg
#   inflating: dataset/airplanes/airplane228.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane228.jpg
#   inflating: dataset/airplanes/airplane202.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane202.jpg
#   inflating: dataset/airplanes/airplane216.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane216.jpg
#   inflating: dataset/airplanes/airplane174.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane174.jpg
#   inflating: dataset/airplanes/airplane160.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane160.jpg
#   inflating: dataset/airplanes/airplane148.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane148.jpg
#   inflating: dataset/airplanes/airplane49.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane49.jpg
#   inflating: dataset/airplanes/airplane410.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane410.jpg
#   inflating: dataset/airplanes/airplane376.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane376.jpg
#   inflating: dataset/airplanes/airplane389.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane389.jpg
#   inflating: dataset/airplanes/airplane363.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane363.jpg
#   inflating: dataset/airplanes/airplane411.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane411.jpg
#   inflating: dataset/airplanes/airplane74.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane74.jpg
#   inflating: dataset/airplanes/airplane175.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane175.jpg
#   inflating: dataset/airplanes/airplane2.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane2.jpg
#   inflating: dataset/airplanes/airplane203.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane203.jpg
#   inflating: dataset/airplanes/airplane159.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane159.jpg
#   inflating: dataset/airplanes/airplane165.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane165.jpg
#   inflating: dataset/airplanes/airplane64.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane64.jpg
#   inflating: dataset/airplanes/airplane58.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane58.jpg
#   inflating: dataset/airplanes/airplane415.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane415.jpg
#   inflating: dataset/airplanes/airplane401.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane401.jpg
#   inflating: dataset/airplanes/airplane400.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane400.jpg
#   inflating: dataset/airplanes/airplane366.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane366.jpg
#   inflating: dataset/airplanes/airplane428.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane428.jpg
#   inflating: dataset/airplanes/airplane65.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane65.jpg
#   inflating: dataset/airplanes/airplane158.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane158.jpg
#   inflating: dataset/airplanes/airplane206.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane206.jpg
#   inflating: dataset/airplanes/airplane238.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane238.jpg
#   inflating: dataset/airplanes/airplane210.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane210.jpg
#   inflating: dataset/airplanes/airplane204.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane204.jpg
#   inflating: dataset/airplanes/airplane5.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane5.jpg
#   inflating: dataset/airplanes/airplane199.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane199.jpg
#   inflating: dataset/airplanes/airplane364.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane364.jpg
#   inflating: dataset/airplanes/airplane416.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane416.jpg
#   inflating: dataset/airplanes/airplane370.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane370.jpg
#   inflating: dataset/airplanes/airplane365.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane365.jpg
#   inflating: dataset/airplanes/airplane403.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane403.jpg
#   inflating: dataset/airplanes/airplane72.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane72.jpg
#   inflating: dataset/airplanes/airplane66.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane66.jpg
#   inflating: dataset/airplanes/airplane198.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane198.jpg
#   inflating: dataset/airplanes/airplane167.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane167.jpg
#   inflating: dataset/airplanes/airplane205.jpg
#   inflating: __MACOSX/dataset/airplanes/._airplane205.jpg
#   inflating: dataset/motorboat/motorboat64.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat64.jpg
#   inflating: dataset/motorboat/motorboat132.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat132.jpg
#   inflating: dataset/motorboat/motorboat318.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat318.jpg
#   inflating: dataset/motorboat/motorboat330.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat330.jpg
#   inflating: dataset/motorboat/motorboat324.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat324.jpg
#   inflating: dataset/motorboat/motorboat293.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat293.jpg
#   inflating: dataset/motorboat/motorboat251.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat251.jpg
#   inflating: dataset/motorboat/motorboat245.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat245.jpg
#   inflating: dataset/motorboat/motorboat292.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat292.jpg
#   inflating: dataset/motorboat/motorboat286.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat286.jpg
#   inflating: dataset/motorboat/motorboat319.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat319.jpg
#   inflating: dataset/motorboat/motorboat127.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat127.jpg
#   inflating: dataset/motorboat/motorboat98.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat98.jpg
#   inflating: dataset/motorboat/motorboat131.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat131.jpg
#   inflating: dataset/motorboat/motorboat327.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat327.jpg
#   inflating: dataset/motorboat/motorboat290.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat290.jpg
#   inflating: dataset/motorboat/motorboat284.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat284.jpg
#   inflating: dataset/motorboat/motorboat253.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat253.jpg
#   inflating: dataset/motorboat/motorboat247.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat247.jpg
#   inflating: dataset/motorboat/motorboat291.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat291.jpg
#   inflating: dataset/motorboat/motorboat332.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat332.jpg
#   inflating: dataset/motorboat/motorboat130.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat130.jpg
#   inflating: dataset/motorboat/motorboat124.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat124.jpg
#   inflating: dataset/motorboat/motorboat72.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat72.jpg
#   inflating: dataset/motorboat/motorboat118.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat118.jpg
#   inflating: dataset/motorboat/motorboat89.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat89.jpg
#   inflating: dataset/motorboat/motorboat120.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat120.jpg
#   inflating: dataset/motorboat/motorboat134.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat134.jpg
#   inflating: dataset/motorboat/motorboat322.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat322.jpg
#   inflating: dataset/motorboat/motorboat336.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat336.jpg
#   inflating: dataset/motorboat/motorboat281.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat281.jpg
#   inflating: dataset/motorboat/motorboat242.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat242.jpg
#   inflating: dataset/motorboat/motorboat280.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat280.jpg
#   inflating: dataset/motorboat/motorboat337.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat337.jpg
#   inflating: dataset/motorboat/motorboat323.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat323.jpg
#   inflating: dataset/motorboat/motorboat109.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat109.jpg
#   inflating: dataset/motorboat/motorboat135.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat135.jpg
#   inflating: dataset/motorboat/motorboat121.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat121.jpg
#   inflating: dataset/motorboat/motorboat88.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat88.jpg
#   inflating: dataset/motorboat/motorboat137.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat137.jpg
#   inflating: dataset/motorboat/motorboat123.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat123.jpg
#   inflating: dataset/motorboat/motorboat49.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat49.jpg
#   inflating: dataset/motorboat/motorboat335.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat335.jpg
#   inflating: dataset/motorboat/motorboat241.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat241.jpg
#   inflating: dataset/motorboat/motorboat255.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat255.jpg
#   inflating: dataset/motorboat/motorboat269.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat269.jpg
#   inflating: dataset/motorboat/motorboat268.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat268.jpg
#   inflating: dataset/motorboat/motorboat240.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat240.jpg
#   inflating: dataset/motorboat/motorboat320.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat320.jpg
#   inflating: dataset/motorboat/motorboat334.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat334.jpg
#   inflating: dataset/motorboat/motorboat74.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat74.jpg
#   inflating: dataset/motorboat/motorboat186.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat186.jpg
#   inflating: dataset/motorboat/motorboat151.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat151.jpg
#   inflating: dataset/motorboat/motorboat390.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat390.jpg
#   inflating: dataset/motorboat/motorboat384.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat384.jpg
#   inflating: dataset/motorboat/motorboat409.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat409.jpg
#   inflating: dataset/motorboat/motorboat353.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat353.jpg
#   inflating: dataset/motorboat/motorboat421.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat421.jpg
#   inflating: dataset/motorboat/motorboat346.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat346.jpg
#   inflating: dataset/motorboat/motorboat420.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat420.jpg
#   inflating: dataset/motorboat/motorboat352.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat352.jpg
#   inflating: dataset/motorboat/motorboat391.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat391.jpg
#   inflating: dataset/motorboat/motorboat144.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat144.jpg
#   inflating: dataset/motorboat/motorboat187.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat187.jpg
#   inflating: dataset/motorboat/motorboat193.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat193.jpg
#   inflating: dataset/motorboat/motorboat191.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat191.jpg
#   inflating: dataset/motorboat/motorboat146.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat146.jpg
#   inflating: dataset/motorboat/motorboat152.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat152.jpg
#   inflating: dataset/motorboat/motorboat378.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat378.jpg
#   inflating: dataset/motorboat/motorboat344.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat344.jpg
#   inflating: dataset/motorboat/motorboat219.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat219.jpg
#   inflating: dataset/motorboat/motorboat351.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat351.jpg
#   inflating: dataset/motorboat/motorboat423.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat423.jpg
#   inflating: dataset/motorboat/motorboat386.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat386.jpg
#   inflating: dataset/motorboat/motorboat39.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat39.jpg
#   inflating: dataset/motorboat/motorboat190.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat190.jpg
#   inflating: dataset/motorboat/motorboat180.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat180.jpg
#   inflating: dataset/motorboat/motorboat194.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat194.jpg
#   inflating: dataset/motorboat/motorboat427.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat427.jpg
#   inflating: dataset/motorboat/motorboat369.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat369.jpg
#   inflating: dataset/motorboat/motorboat209.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat209.jpg
#   inflating: dataset/motorboat/motorboat220.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat220.jpg
#   inflating: dataset/motorboat/motorboat340.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat340.jpg
#   inflating: dataset/motorboat/motorboat426.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat426.jpg
#   inflating: dataset/motorboat/motorboat397.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat397.jpg
#   inflating: dataset/motorboat/motorboat383.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat383.jpg
#   inflating: dataset/motorboat/motorboat14.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat14.jpg
#   inflating: dataset/motorboat/motorboat156.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat156.jpg
#   inflating: dataset/motorboat/motorboat28.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat28.jpg
#   inflating: dataset/motorboat/motorboat142.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat142.jpg
#   inflating: dataset/motorboat/motorboat154.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat154.jpg
#   inflating: dataset/motorboat/motorboat430.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat430.jpg
#   inflating: dataset/motorboat/motorboat342.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat342.jpg
#   inflating: dataset/motorboat/motorboat419.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat419.jpg
#   inflating: dataset/motorboat/motorboat9.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat9.jpg
#   inflating: dataset/motorboat/motorboat343.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat343.jpg
#   inflating: dataset/motorboat/motorboat357.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat357.jpg
#   inflating: dataset/motorboat/motorboat380.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat380.jpg
#   inflating: dataset/motorboat/motorboat394.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat394.jpg
#   inflating: dataset/motorboat/motorboat17.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat17.jpg
#   inflating: dataset/motorboat/motorboat169.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat169.jpg
#   inflating: dataset/motorboat/motorboat26.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat26.jpg
#   inflating: dataset/motorboat/motorboat158.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat158.jpg
#   inflating: dataset/motorboat/motorboat32.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat32.jpg
#   inflating: dataset/motorboat/motorboat428.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat428.jpg
#   inflating: dataset/motorboat/motorboat366.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat366.jpg
#   inflating: dataset/motorboat/motorboat400.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat400.jpg
#   inflating: dataset/motorboat/motorboat206.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat206.jpg
#   inflating: dataset/motorboat/motorboat401.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat401.jpg
#   inflating: dataset/motorboat/motorboat415.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat415.jpg
#   inflating: dataset/motorboat/motorboat398.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat398.jpg
#   inflating: dataset/motorboat/motorboat165.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat165.jpg
#   inflating: dataset/motorboat/motorboat33.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat33.jpg
#   inflating: dataset/motorboat/motorboat159.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat159.jpg
#   inflating: dataset/motorboat/motorboat27.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat27.jpg
#   inflating: dataset/motorboat/motorboat198.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat198.jpg
#   inflating: dataset/motorboat/motorboat31.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat31.jpg
#   inflating: dataset/motorboat/motorboat167.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat167.jpg
#   inflating: dataset/motorboat/motorboat19.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat19.jpg
#   inflating: dataset/motorboat/motorboat7.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat7.jpg
#   inflating: dataset/motorboat/motorboat365.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat365.jpg
#   inflating: dataset/motorboat/motorboat205.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat205.jpg
#   inflating: dataset/motorboat/motorboat204.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat204.jpg
#   inflating: dataset/motorboat/motorboat210.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat210.jpg
#   inflating: dataset/motorboat/motorboat238.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat238.jpg
#   inflating: dataset/motorboat/motorboat370.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat370.jpg
#   inflating: dataset/motorboat/motorboat416.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat416.jpg
#   inflating: dataset/motorboat/motorboat364.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat364.jpg
#   inflating: dataset/motorboat/motorboat30.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat30.jpg
#   inflating: dataset/motorboat/motorboat199.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat199.jpg
#   inflating: dataset/motorboat/motorboat176.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat176.jpg
#   inflating: dataset/motorboat/motorboat360.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat360.jpg
#   inflating: dataset/motorboat/motorboat374.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat374.jpg
#   inflating: dataset/motorboat/motorboat348.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat348.jpg
#   inflating: dataset/motorboat/motorboat228.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat228.jpg
#   inflating: dataset/motorboat/motorboat201.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat201.jpg
#   inflating: dataset/motorboat/motorboat349.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat349.jpg
#   inflating: dataset/motorboat/motorboat375.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat375.jpg
#   inflating: dataset/motorboat/motorboat361.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat361.jpg
#   inflating: dataset/motorboat/motorboat407.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat407.jpg
#   inflating: dataset/motorboat/motorboat177.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat177.jpg
#   inflating: dataset/motorboat/motorboat23.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat23.jpg
#   inflating: dataset/motorboat/motorboat37.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat37.jpg
#   inflating: dataset/motorboat/motorboat377.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat377.jpg
#   inflating: dataset/motorboat/motorboat411.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat411.jpg
#   inflating: dataset/motorboat/motorboat363.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat363.jpg
#   inflating: dataset/motorboat/motorboat1.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat1.jpg
#   inflating: dataset/motorboat/motorboat203.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat203.jpg
#   inflating: dataset/motorboat/motorboat216.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat216.jpg
#   inflating: dataset/motorboat/motorboat376.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat376.jpg
#   inflating: dataset/motorboat/motorboat410.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat410.jpg
#   inflating: dataset/motorboat/motorboat389.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat389.jpg
#   inflating: dataset/motorboat/motorboat160.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat160.jpg
#   inflating: dataset/motorboat/motorboat79.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat79.jpg
#   inflating: dataset/motorboat/motorboat107.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat107.jpg
#   inflating: dataset/motorboat/motorboat339.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat339.jpg
#   inflating: dataset/motorboat/motorboat311.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat311.jpg
#   inflating: dataset/motorboat/motorboat271.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat271.jpg
#   inflating: dataset/motorboat/motorboat264.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat264.jpg
#   inflating: dataset/motorboat/motorboat258.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat258.jpg
#   inflating: dataset/motorboat/motorboat304.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat304.jpg
#   inflating: dataset/motorboat/motorboat338.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat338.jpg
#   inflating: dataset/motorboat/motorboat78.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat78.jpg
#   inflating: dataset/motorboat/motorboat112.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat112.jpg
#   inflating: dataset/motorboat/motorboat50.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat50.jpg
#   inflating: dataset/motorboat/motorboat93.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat93.jpg
#   inflating: dataset/motorboat/motorboat87.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat87.jpg
#   inflating: dataset/motorboat/motorboat46.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat46.jpg
#   inflating: dataset/motorboat/motorboat104.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat104.jpg
#   inflating: dataset/motorboat/motorboat306.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat306.jpg
#   inflating: dataset/motorboat/motorboat312.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat312.jpg
#   inflating: dataset/motorboat/motorboat272.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat272.jpg
#   inflating: dataset/motorboat/motorboat267.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat267.jpg
#   inflating: dataset/motorboat/motorboat105.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat105.jpg
#   inflating: dataset/motorboat/motorboat47.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat47.jpg
#   inflating: dataset/motorboat/motorboat80.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat80.jpg
#   inflating: dataset/motorboat/motorboat101.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat101.jpg
#   inflating: dataset/motorboat/motorboat115.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat115.jpg
#   inflating: dataset/motorboat/motorboat43.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat43.jpg
#   inflating: dataset/motorboat/motorboat303.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat303.jpg
#   inflating: dataset/motorboat/motorboat317.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat317.jpg
#   inflating: dataset/motorboat/motorboat262.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat262.jpg
#   inflating: dataset/motorboat/motorboat276.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat276.jpg
#   inflating: dataset/motorboat/motorboat289.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat289.jpg
#   inflating: dataset/motorboat/motorboat56.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat56.jpg
#   inflating: dataset/motorboat/motorboat114.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat114.jpg
#   inflating: dataset/motorboat/motorboat81.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat81.jpg
#   inflating: dataset/motorboat/motorboat83.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat83.jpg
#   inflating: dataset/motorboat/motorboat97.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat97.jpg
#   inflating: dataset/motorboat/motorboat116.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat116.jpg
#   inflating: dataset/motorboat/motorboat54.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat54.jpg
#   inflating: dataset/motorboat/motorboat314.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat314.jpg
#   inflating: dataset/motorboat/motorboat260.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat260.jpg
#   inflating: dataset/motorboat/motorboat249.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat249.jpg
#   inflating: dataset/motorboat/motorboat261.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat261.jpg
#   inflating: dataset/motorboat/motorboat301.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat301.jpg
#   inflating: dataset/motorboat/motorboat315.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat315.jpg
#   inflating: dataset/motorboat/motorboat55.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat55.jpg
#   inflating: dataset/motorboat/motorboat69.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat69.jpg
#   inflating: dataset/motorboat/motorboat117.jpg
#   inflating: __MACOSX/dataset/motorboat/._motorboat117.jpg
#   inflating: dataset/motorcycles/motorcycle142.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle142.jpg
#   inflating: dataset/motorcycles/motorcycle156.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle156.jpg
#   inflating: dataset/motorcycles/motorcycle383.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle383.jpg
#   inflating: dataset/motorcycles/motorcycle397.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle397.jpg
#   inflating: dataset/motorcycles/motorcycle340.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle340.jpg
#   inflating: dataset/motorcycles/motorcycle234.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle234.jpg
#   inflating: dataset/motorcycles/motorcycle220.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle220.jpg
#   inflating: dataset/motorcycles/motorcycle37.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle37.jpg
#   inflating: dataset/motorcycles/motorcycle23.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle23.jpg
#   inflating: dataset/motorcycles/motorcycle209.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle209.jpg
#   inflating: dataset/motorcycles/motorcycle369.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle369.jpg
#   inflating: dataset/motorcycles/motorcycle341.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle341.jpg
#   inflating: dataset/motorcycles/motorcycle194.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle194.jpg
#   inflating: dataset/motorcycles/motorcycle180.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle180.jpg
#   inflating: dataset/motorcycles/motorcycle182.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle182.jpg
#   inflating: dataset/motorcycles/motorcycle155.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle155.jpg
#   inflating: dataset/motorcycles/motorcycle169.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle169.jpg
#   inflating: dataset/motorcycles/motorcycle394.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle394.jpg
#   inflating: dataset/motorcycles/motorcycle380.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle380.jpg
#   inflating: dataset/motorcycles/motorcycle342.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle342.jpg
#   inflating: dataset/motorcycles/motorcycle154.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle154.jpg
#   inflating: dataset/motorcycles/motorcycle183.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle183.jpg
#   inflating: dataset/motorcycles/motorcycle193.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle193.jpg
#   inflating: dataset/motorcycles/motorcycle187.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle187.jpg
#   inflating: dataset/motorcycles/motorcycle144.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle144.jpg
#   inflating: dataset/motorcycles/motorcycle391.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle391.jpg
#   inflating: dataset/motorcycles/motorcycle352.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle352.jpg
#   inflating: dataset/motorcycles/motorcycle346.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle346.jpg
#   inflating: dataset/motorcycles/motorcycle232.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle232.jpg
#   inflating: dataset/motorcycles/.DS_Store
#   inflating: __MACOSX/dataset/motorcycles/._.DS_Store
#   inflating: dataset/motorcycles/motorcycle31.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle31.jpg
#   inflating: dataset/motorcycles/motorcycle19.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle19.jpg
#   inflating: dataset/motorcycles/motorcycle353.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle353.jpg
#   inflating: dataset/motorcycles/motorcycle390.jpg
#   inflating: __MACOSX/dataset/motorcycles/._motorcycle390.jpg
# ...
#   inflating: __MACOSX/dataset/trains/._train98.jpg
#   inflating: dataset/trains/train216.jpg
#   inflating: __MACOSX/dataset/trains/._train216.jpg
#   inflating: dataset/trains/train202.jpg
#   inflating: __MACOSX/dataset/trains/._train202.jpg
#   inflating: dataset/trains/train410.jpg
#   inflating: __MACOSX/dataset/trains/._train410.jpg
#   inflating: dataset/trains/train389.jpg
#   inflating: __MACOSX/dataset/trains/._train389.jpg
#   inflating: dataset/trains/train174.jpg
#   inflating: __MACOSX/dataset/trains/._train174.jpg
#   inflating: dataset/trains/train148.jpg
#   inflating: __MACOSX/dataset/trains/._train148.jpg
#   inflating: dataset/trains/train175.jpg
#   inflating: __MACOSX/dataset/trains/._train175.jpg
#   inflating: dataset/trains/train377.jpg
#   inflating: __MACOSX/dataset/trains/._train377.jpg
#   inflating: dataset/trains/train411.jpg
#   inflating: __MACOSX/dataset/trains/._train411.jpg
#   inflating: dataset/trains/train363.jpg
#   inflating: __MACOSX/dataset/trains/._train363.jpg
#   inflating: dataset/trains/train203.jpg
#   inflating: __MACOSX/dataset/trains/._train203.jpg
#   inflating: dataset/trains/train72.jpg
#   inflating: __MACOSX/dataset/trains/._train72.jpg
#   inflating: dataset/trains/train66.jpg
#   inflating: __MACOSX/dataset/trains/._train66.jpg
#   inflating: dataset/trains/train58.jpg
#   inflating: __MACOSX/dataset/trains/._train58.jpg
#   inflating: dataset/trains/train201.jpg
#   inflating: __MACOSX/dataset/trains/._train201.jpg
#   inflating: dataset/trains/train375.jpg
#   inflating: __MACOSX/dataset/trains/._train375.jpg
#   inflating: dataset/trains/train407.jpg
#   inflating: __MACOSX/dataset/trains/._train407.jpg
#   inflating: dataset/trains/train349.jpg
#   inflating: __MACOSX/dataset/trains/._train349.jpg
#   inflating: dataset/trains/train177.jpg
#   inflating: __MACOSX/dataset/trains/._train177.jpg
#   inflating: dataset/trains/train163.jpg
#   inflating: __MACOSX/dataset/trains/._train163.jpg
#   inflating: dataset/trains/train176.jpg
#   inflating: __MACOSX/dataset/trains/._train176.jpg
#   inflating: dataset/trains/train348.jpg
#   inflating: __MACOSX/dataset/trains/._train348.jpg
#   inflating: dataset/trains/train360.jpg
#   inflating: __MACOSX/dataset/trains/._train360.jpg
#   inflating: dataset/trains/train374.jpg
#   inflating: __MACOSX/dataset/trains/._train374.jpg
#   inflating: dataset/trains/train228.jpg
#   inflating: __MACOSX/dataset/trains/._train228.jpg
#   inflating: dataset/trains/train49.jpg
#   inflating: __MACOSX/dataset/trains/._train49.jpg
#   inflating: dataset/trains/train238.jpg
#   inflating: __MACOSX/dataset/trains/._train238.jpg
#   inflating: dataset/trains/train204.jpg
#   inflating: __MACOSX/dataset/trains/._train204.jpg
#   inflating: dataset/trains/train370.jpg
#   inflating: __MACOSX/dataset/trains/._train370.jpg
#   inflating: dataset/trains/train416.jpg
#   inflating: __MACOSX/dataset/trains/._train416.jpg
#   inflating: dataset/trains/train199.jpg
#   inflating: __MACOSX/dataset/trains/._train199.jpg
#   inflating: dataset/trains/train198.jpg
#   inflating: __MACOSX/dataset/trains/._train198.jpg
#   inflating: dataset/trains/train403.jpg
#   inflating: __MACOSX/dataset/trains/._train403.jpg
#   inflating: dataset/trains/train365.jpg
#   inflating: __MACOSX/dataset/trains/._train365.jpg
#   inflating: dataset/trains/train205.jpg
#   inflating: __MACOSX/dataset/trains/._train205.jpg
#   inflating: dataset/trains/train74.jpg
#   inflating: __MACOSX/dataset/trains/._train74.jpg
#   inflating: dataset/trains/train89.jpg
#   inflating: __MACOSX/dataset/trains/._train89.jpg
#   inflating: dataset/trains/train401.jpg
#   inflating: __MACOSX/dataset/trains/._train401.jpg
#   inflating: dataset/trains/train415.jpg
#   inflating: __MACOSX/dataset/trains/._train415.jpg
#   inflating: dataset/trains/train398.jpg
#   inflating: __MACOSX/dataset/trains/._train398.jpg
#   inflating: dataset/trains/train159.jpg
#   inflating: __MACOSX/dataset/trains/._train159.jpg
#   inflating: dataset/trains/train165.jpg
#   inflating: __MACOSX/dataset/trains/._train165.jpg
#   inflating: dataset/trains/train158.jpg
#   inflating: __MACOSX/dataset/trains/._train158.jpg
#   inflating: dataset/trains/train366.jpg
#   inflating: __MACOSX/dataset/trains/._train366.jpg
#   inflating: dataset/trains/train400.jpg
#   inflating: __MACOSX/dataset/trains/._train400.jpg
#   inflating: dataset/trains/train428.jpg
#   inflating: __MACOSX/dataset/trains/._train428.jpg
#   inflating: dataset/trains/train206.jpg
#   inflating: __MACOSX/dataset/trains/._train206.jpg
#   inflating: dataset/trains/train88.jpg
#   inflating: __MACOSX/dataset/trains/._train88.jpg
#   inflating: dataset/trains/train77.jpg
#   inflating: __MACOSX/dataset/trains/._train77.jpg
#   inflating: dataset/trains/train46.jpg
#   inflating: __MACOSX/dataset/trains/._train46.jpg
#   inflating: dataset/trains/train343.jpg
#   inflating: __MACOSX/dataset/trains/._train343.jpg
#   inflating: dataset/trains/train357.jpg
#   inflating: __MACOSX/dataset/trains/._train357.jpg
#   inflating: dataset/trains/train419.jpg
#   inflating: __MACOSX/dataset/trains/._train419.jpg
#   inflating: dataset/trains/train380.jpg
#   inflating: __MACOSX/dataset/trains/._train380.jpg
#   inflating: dataset/trains/train394.jpg
#   inflating: __MACOSX/dataset/trains/._train394.jpg
#   inflating: dataset/trains/train154.jpg
#   inflating: __MACOSX/dataset/trains/._train154.jpg
#   inflating: dataset/trains/train430.jpg
#   inflating: __MACOSX/dataset/trains/._train430.jpg
#   inflating: dataset/trains/train342.jpg
#   inflating: __MACOSX/dataset/trains/._train342.jpg
#   inflating: dataset/trains/train5.jpg
#   inflating: __MACOSX/dataset/trains/._train5.jpg
#   inflating: dataset/trains/train47.jpg
#   inflating: __MACOSX/dataset/trains/._train47.jpg
#   inflating: dataset/trains/train51.jpg
#   inflating: __MACOSX/dataset/trains/._train51.jpg
#   inflating: dataset/trains/train220.jpg
#   inflating: __MACOSX/dataset/trains/._train220.jpg
#   inflating: dataset/trains/train234.jpg
#   inflating: __MACOSX/dataset/trains/._train234.jpg
#   inflating: dataset/trains/train7.jpg
#   inflating: __MACOSX/dataset/trains/._train7.jpg
#   inflating: dataset/trains/train432.jpg
#   inflating: __MACOSX/dataset/trains/._train432.jpg
#   inflating: dataset/trains/train426.jpg
#   inflating: __MACOSX/dataset/trains/._train426.jpg
#   inflating: dataset/trains/train397.jpg
#   inflating: __MACOSX/dataset/trains/._train397.jpg
#   inflating: dataset/trains/train383.jpg
#   inflating: __MACOSX/dataset/trains/._train383.jpg
#   inflating: dataset/trains/train156.jpg
#   inflating: __MACOSX/dataset/trains/._train156.jpg
#   inflating: dataset/trains/train142.jpg
#   inflating: __MACOSX/dataset/trains/._train142.jpg
#   inflating: dataset/trains/train180.jpg
#   inflating: __MACOSX/dataset/trains/._train180.jpg
#   inflating: dataset/trains/train194.jpg
#   inflating: __MACOSX/dataset/trains/._train194.jpg
#   inflating: dataset/trains/train369.jpg
#   inflating: __MACOSX/dataset/trains/._train369.jpg
#   inflating: dataset/trains/train427.jpg
#   inflating: __MACOSX/dataset/trains/._train427.jpg
#   inflating: dataset/trains/train433.jpg
#   inflating: __MACOSX/dataset/trains/._train433.jpg
#   inflating: dataset/trains/train209.jpg
#   inflating: __MACOSX/dataset/trains/._train209.jpg
#   inflating: dataset/trains/train87.jpg
#   inflating: __MACOSX/dataset/trains/._train87.jpg
#   inflating: dataset/trains/train93.jpg
#   inflating: __MACOSX/dataset/trains/._train93.jpg
#   inflating: dataset/trains/train78.jpg
#   inflating: __MACOSX/dataset/trains/._train78.jpg
#   inflating: dataset/trains/train50.jpg
#   inflating: __MACOSX/dataset/trains/._train50.jpg
#   inflating: dataset/trains/train54.jpg
#   inflating: __MACOSX/dataset/trains/._train54.jpg
#   inflating: dataset/trains/train97.jpg
#   inflating: __MACOSX/dataset/trains/._train97.jpg
#   inflating: dataset/trains/train83.jpg
#   inflating: __MACOSX/dataset/trains/._train83.jpg
#   inflating: dataset/trains/train351.jpg
#   inflating: __MACOSX/dataset/trains/._train351.jpg
#   inflating: dataset/trains/train423.jpg
#   inflating: __MACOSX/dataset/trains/._train423.jpg
#   inflating: dataset/trains/train386.jpg
#   inflating: __MACOSX/dataset/trains/._train386.jpg
#   inflating: dataset/trains/train190.jpg
#   inflating: __MACOSX/dataset/trains/._train190.jpg
#   inflating: dataset/trains/train146.jpg
#   inflating: __MACOSX/dataset/trains/._train146.jpg
#   inflating: dataset/trains/train152.jpg
#   inflating: __MACOSX/dataset/trains/._train152.jpg
#   inflating: dataset/trains/train344.jpg
#   inflating: __MACOSX/dataset/trains/._train344.jpg
#   inflating: dataset/trains/train378.jpg
#   inflating: __MACOSX/dataset/trains/._train378.jpg
#   inflating: dataset/trains/train41.jpg
#   inflating: __MACOSX/dataset/trains/._train41.jpg
#   inflating: dataset/trains/train55.jpg
#   inflating: __MACOSX/dataset/trains/._train55.jpg
#   inflating: dataset/trains/train69.jpg
#   inflating: __MACOSX/dataset/trains/._train69.jpg
#   inflating: dataset/trains/train43.jpg
#   inflating: __MACOSX/dataset/trains/._train43.jpg
#   inflating: dataset/trains/train80.jpg
#   inflating: __MACOSX/dataset/trains/._train80.jpg
#   inflating: dataset/trains/train1.jpg
#   inflating: __MACOSX/dataset/trains/._train1.jpg
#   inflating: dataset/trains/train346.jpg
#   inflating: __MACOSX/dataset/trains/._train346.jpg
#   inflating: dataset/trains/train420.jpg
#   inflating: __MACOSX/dataset/trains/._train420.jpg
#   inflating: dataset/trains/train352.jpg
#   inflating: __MACOSX/dataset/trains/._train352.jpg
#   inflating: dataset/trains/train391.jpg
#   inflating: __MACOSX/dataset/trains/._train391.jpg
#   inflating: dataset/trains/train144.jpg
#   inflating: __MACOSX/dataset/trains/._train144.jpg
#   inflating: dataset/trains/train187.jpg
#   inflating: __MACOSX/dataset/trains/._train187.jpg
#   inflating: dataset/trains/train193.jpg
#   inflating: __MACOSX/dataset/trains/._train193.jpg
#   inflating: dataset/trains/train186.jpg
#   inflating: __MACOSX/dataset/trains/._train186.jpg
#   inflating: dataset/trains/train151.jpg
#   inflating: __MACOSX/dataset/trains/._train151.jpg
#   inflating: dataset/trains/train390.jpg
#   inflating: __MACOSX/dataset/trains/._train390.jpg
#   inflating: dataset/trains/train384.jpg
#   inflating: __MACOSX/dataset/trains/._train384.jpg
#   inflating: dataset/trains/train435.jpg
#   inflating: __MACOSX/dataset/trains/._train435.jpg
#   inflating: dataset/trains/train353.jpg
#   inflating: __MACOSX/dataset/trains/._train353.jpg
#   inflating: dataset/trains/train409.jpg
#   inflating: __MACOSX/dataset/trains/._train409.jpg
#   inflating: dataset/trains/train81.jpg
#   inflating: __MACOSX/dataset/trains/._train81.jpg
#   inflating: dataset/trains/train56.jpg
#   inflating: __MACOSX/dataset/trains/._train56.jpg
#   inflating: dataset/trains/train19.jpg
#   inflating: __MACOSX/dataset/trains/._train19.jpg
#   inflating: dataset/trains/train240.jpg
#   inflating: __MACOSX/dataset/trains/._train240.jpg
#   inflating: dataset/trains/train268.jpg
#   inflating: __MACOSX/dataset/trains/._train268.jpg
#   inflating: dataset/trains/train320.jpg
#   inflating: __MACOSX/dataset/trains/._train320.jpg
#   inflating: dataset/trains/train334.jpg
#   inflating: __MACOSX/dataset/trains/._train334.jpg
#   inflating: dataset/trains/train137.jpg
#   inflating: __MACOSX/dataset/trains/._train137.jpg
#   inflating: dataset/trains/train123.jpg
#   inflating: __MACOSX/dataset/trains/._train123.jpg
#   inflating: dataset/trains/train309.jpg
#   inflating: __MACOSX/dataset/trains/._train309.jpg
#   inflating: dataset/trains/train335.jpg
#   inflating: __MACOSX/dataset/trains/._train335.jpg
#   inflating: dataset/trains/train447.jpg
#   inflating: __MACOSX/dataset/trains/._train447.jpg
#   inflating: dataset/trains/train269.jpg
#   inflating: __MACOSX/dataset/trains/._train269.jpg
#   inflating: dataset/trains/train241.jpg
#   inflating: __MACOSX/dataset/trains/._train241.jpg
#   inflating: dataset/trains/train255.jpg
#   inflating: __MACOSX/dataset/trains/._train255.jpg
#   inflating: dataset/trains/train32.jpg
#   inflating: __MACOSX/dataset/trains/._train32.jpg
#   inflating: dataset/trains/train26.jpg
#   inflating: __MACOSX/dataset/trains/._train26.jpg
#   inflating: dataset/trains/train257.jpg
#   inflating: __MACOSX/dataset/trains/._train257.jpg
#   inflating: dataset/trains/train280.jpg
#   inflating: __MACOSX/dataset/trains/._train280.jpg
#   inflating: dataset/trains/train337.jpg
#   inflating: __MACOSX/dataset/trains/._train337.jpg
#   inflating: dataset/trains/train451.jpg
#   inflating: __MACOSX/dataset/trains/._train451.jpg
#   inflating: dataset/trains/train445.jpg
#   inflating: __MACOSX/dataset/trains/._train445.jpg
#   inflating: dataset/trains/train323.jpg
#   inflating: __MACOSX/dataset/trains/._train323.jpg
#   inflating: dataset/trains/train121.jpg
#   inflating: __MACOSX/dataset/trains/._train121.jpg
#   inflating: dataset/trains/train109.jpg
#   inflating: __MACOSX/dataset/trains/._train109.jpg
#   inflating: dataset/trains/train134.jpg
#   inflating: __MACOSX/dataset/trains/._train134.jpg
#   inflating: dataset/trains/train281.jpg
#   inflating: __MACOSX/dataset/trains/._train281.jpg
#   inflating: dataset/trains/train242.jpg
#   inflating: __MACOSX/dataset/trains/._train242.jpg
#   inflating: dataset/trains/train27.jpg
#   inflating: __MACOSX/dataset/trains/._train27.jpg
#   inflating: dataset/trains/train33.jpg
#   inflating: __MACOSX/dataset/trains/._train33.jpg
#   inflating: dataset/trains/train37.jpg
#   inflating: __MACOSX/dataset/trains/._train37.jpg
#   inflating: dataset/trains/train23.jpg
#   inflating: __MACOSX/dataset/trains/._train23.jpg
#   inflating: dataset/trains/train291.jpg
#   inflating: __MACOSX/dataset/trains/._train291.jpg
#   inflating: dataset/trains/train454.jpg
#   inflating: __MACOSX/dataset/trains/._train454.jpg
#   inflating: dataset/trains/train332.jpg
#   inflating: __MACOSX/dataset/trains/._train332.jpg
#   inflating: dataset/trains/train326.jpg
#   inflating: __MACOSX/dataset/trains/._train326.jpg
#   inflating: dataset/trains/train440.jpg
#   inflating: __MACOSX/dataset/trains/._train440.jpg
#   inflating: dataset/trains/train118.jpg
#   inflating: __MACOSX/dataset/trains/._train118.jpg
#   inflating: dataset/trains/train130.jpg
#   inflating: __MACOSX/dataset/trains/._train130.jpg
#   inflating: dataset/trains/train124.jpg
#   inflating: __MACOSX/dataset/trains/._train124.jpg
#   inflating: dataset/trains/train131.jpg
#   inflating: __MACOSX/dataset/trains/._train131.jpg
#   inflating: dataset/trains/train455.jpg
#   inflating: __MACOSX/dataset/trains/._train455.jpg
#   inflating: dataset/trains/train290.jpg
#   inflating: __MACOSX/dataset/trains/._train290.jpg
#   inflating: dataset/trains/train253.jpg
#   inflating: __MACOSX/dataset/trains/._train253.jpg
#   inflating: dataset/trains/train251.jpg
#   inflating: __MACOSX/dataset/trains/._train251.jpg
#   inflating: dataset/trains/train245.jpg
#   inflating: __MACOSX/dataset/trains/._train245.jpg
#   inflating: dataset/trains/train292.jpg
#   inflating: __MACOSX/dataset/trains/._train292.jpg
#   inflating: dataset/trains/train286.jpg
#   inflating: __MACOSX/dataset/trains/._train286.jpg
#   inflating: dataset/trains/train443.jpg
#   inflating: __MACOSX/dataset/trains/._train443.jpg
#   inflating: dataset/trains/train457.jpg
#   inflating: __MACOSX/dataset/trains/._train457.jpg
#   inflating: dataset/trains/train127.jpg
#   inflating: __MACOSX/dataset/trains/._train127.jpg
#   inflating: dataset/trains/train132.jpg
#   inflating: __MACOSX/dataset/trains/._train132.jpg
#   inflating: dataset/trains/train330.jpg
#   inflating: __MACOSX/dataset/trains/._train330.jpg
#   inflating: dataset/trains/train318.jpg
#   inflating: __MACOSX/dataset/trains/._train318.jpg

# %%
from fastai.vision.all import *
from pathlib import Path

# TODO - change the path!
path = Path('./dataset') / 'train'

dls = ImageDataLoaders.from_folder(
    path,                 # Path to the train folder
    train='.',            # Use the entire train folder for splitting
    valid_pct=0.2,        # 20% of the data will be used for validation
    seed=42,              # Set a seed for reproducibility
    item_tfms=Resize(460),# Resize the images to 460x460 (or your desired size)
    batch_tfms=aug_transforms(size=224, min_scale=0.75), # Data augmentation 
    bs=64                 # Batch size 64
)

dls.show_batch(max_n=9)

# %%
import warnings

# to ignore the palette warnings
warnings.filterwarnings(
    "ignore",
    message="Palette images with Transparency expressed in bytes should be converted to RGBA images",
    category=UserWarning
)

# %% [markdown]
# ## Train the model
#
#   1. Choose a pretrained model.
#   2. Determine the optimal learning rate using the learning rate finder.
#   3. Fine-tune the pretrained model to adapt it to your dataset.
#
# Regarding the model, use rather [something smaller](https://www.kaggle.com/code/jhoward/which-image-models-are-best) from `timm` package. Architectures like convexnet, resnet, vgg or mobilenet should be fine.

# %%
# TODO - you can change resnet18 to other architecture
# from timm import list_models
# list_models(pretrained=True)
learn = vision_learner(dls, resnet18, metrics=error_rate)

# %%
from timm import list_models
list_models(pretrained=True)
# Out:
# ['bat_resnext26ts.ch_in1k',
#  'beit_base_patch16_224.in22k_ft_in22k',
#  'beit_base_patch16_224.in22k_ft_in22k_in1k',
#  'beit_base_patch16_384.in22k_ft_in22k_in1k',
#  'beit_large_patch16_224.in22k_ft_in22k',
#  'beit_large_patch16_224.in22k_ft_in22k_in1k',
#  'beit_large_patch16_384.in22k_ft_in22k_in1k',
#  'beit_large_patch16_512.in22k_ft_in22k_in1k',
#  'beitv2_base_patch16_224.in1k_ft_in1k',
#  'beitv2_base_patch16_224.in1k_ft_in22k',
#  'beitv2_base_patch16_224.in1k_ft_in22k_in1k',
#  'beitv2_large_patch16_224.in1k_ft_in1k',
#  'beitv2_large_patch16_224.in1k_ft_in22k',
#  'beitv2_large_patch16_224.in1k_ft_in22k_in1k',
#  'botnet26t_256.c1_in1k',
#  'caformer_b36.sail_in1k',
#  'caformer_b36.sail_in1k_384',
#  'caformer_b36.sail_in22k',
#  'caformer_b36.sail_in22k_ft_in1k',
#  'caformer_b36.sail_in22k_ft_in1k_384',
#  'caformer_m36.sail_in1k',
#  'caformer_m36.sail_in1k_384',
#  'caformer_m36.sail_in22k',
#  'caformer_m36.sail_in22k_ft_in1k',
#  'caformer_m36.sail_in22k_ft_in1k_384',
#  'caformer_s18.sail_in1k',
#  'caformer_s18.sail_in1k_384',
#  'caformer_s18.sail_in22k',
#  'caformer_s18.sail_in22k_ft_in1k',
#  'caformer_s18.sail_in22k_ft_in1k_384',
#  'caformer_s36.sail_in1k',
#  'caformer_s36.sail_in1k_384',
#  'caformer_s36.sail_in22k',
#  'caformer_s36.sail_in22k_ft_in1k',
#  'caformer_s36.sail_in22k_ft_in1k_384',
#  'cait_m36_384.fb_dist_in1k',
#  'cait_m48_448.fb_dist_in1k',
#  'cait_s24_224.fb_dist_in1k',
#  'cait_s24_384.fb_dist_in1k',
#  'cait_s36_384.fb_dist_in1k',
#  'cait_xs24_384.fb_dist_in1k',
#  'cait_xxs24_224.fb_dist_in1k',
#  'cait_xxs24_384.fb_dist_in1k',
#  'cait_xxs36_224.fb_dist_in1k',
#  'cait_xxs36_384.fb_dist_in1k',
#  'coat_lite_medium.in1k',
#  'coat_lite_medium_384.in1k',
#  'coat_lite_mini.in1k',
#  'coat_lite_small.in1k',
#  'coat_lite_tiny.in1k',
#  'coat_mini.in1k',
#  'coat_small.in1k',
#  'coat_tiny.in1k',
#  'coatnet_0_rw_224.sw_in1k',
#  'coatnet_1_rw_224.sw_in1k',
#  'coatnet_2_rw_224.sw_in12k',
#  'coatnet_2_rw_224.sw_in12k_ft_in1k',
#  'coatnet_3_rw_224.sw_in12k',
#  'coatnet_bn_0_rw_224.sw_in1k',
#  'coatnet_nano_rw_224.sw_in1k',
#  'coatnet_rmlp_1_rw2_224.sw_in12k',
#  'coatnet_rmlp_1_rw2_224.sw_in12k_ft_in1k',
#  'coatnet_rmlp_1_rw_224.sw_in1k',
#  'coatnet_rmlp_2_rw_224.sw_in1k',
#  'coatnet_rmlp_2_rw_224.sw_in12k',
#  'coatnet_rmlp_2_rw_224.sw_in12k_ft_in1k',
#  'coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k',
#  'coatnet_rmlp_nano_rw_224.sw_in1k',
#  'coatnext_nano_rw_224.sw_in1k',
#  'convformer_b36.sail_in1k',
#  'convformer_b36.sail_in1k_384',
#  'convformer_b36.sail_in22k',
#  'convformer_b36.sail_in22k_ft_in1k',
#  'convformer_b36.sail_in22k_ft_in1k_384',
#  'convformer_m36.sail_in1k',
#  'convformer_m36.sail_in1k_384',
#  'convformer_m36.sail_in22k',
#  'convformer_m36.sail_in22k_ft_in1k',
#  'convformer_m36.sail_in22k_ft_in1k_384',
#  'convformer_s18.sail_in1k',
#  'convformer_s18.sail_in1k_384',
#  'convformer_s18.sail_in22k',
#  'convformer_s18.sail_in22k_ft_in1k',
#  'convformer_s18.sail_in22k_ft_in1k_384',
#  'convformer_s36.sail_in1k',
#  'convformer_s36.sail_in1k_384',
#  'convformer_s36.sail_in22k',
#  'convformer_s36.sail_in22k_ft_in1k',
#  'convformer_s36.sail_in22k_ft_in1k_384',
#  'convit_base.fb_in1k',
#  'convit_small.fb_in1k',
#  'convit_tiny.fb_in1k',
#  'convmixer_768_32.in1k',
#  'convmixer_1024_20_ks9_p14.in1k',
#  'convmixer_1536_20.in1k',
#  'convnext_atto.d2_in1k',
#  'convnext_atto_ols.a2_in1k',
#  'convnext_base.clip_laion2b',
#  'convnext_base.clip_laion2b_augreg',
#  'convnext_base.clip_laion2b_augreg_ft_in1k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k_in1k',
#  'convnext_base.clip_laion2b_augreg_ft_in12k_in1k_384',
#  'convnext_base.clip_laiona',
#  'convnext_base.clip_laiona_320',
#  'convnext_base.clip_laiona_augreg_320',
#  'convnext_base.clip_laiona_augreg_ft_in1k_384',
#  'convnext_base.fb_in1k',
#  'convnext_base.fb_in22k',
#  'convnext_base.fb_in22k_ft_in1k',
#  'convnext_base.fb_in22k_ft_in1k_384',
#  'convnext_femto.d1_in1k',
#  'convnext_femto_ols.d1_in1k',
#  'convnext_large.fb_in1k',
#  'convnext_large.fb_in22k',
#  'convnext_large.fb_in22k_ft_in1k',
#  'convnext_large.fb_in22k_ft_in1k_384',
#  'convnext_large_mlp.clip_laion2b_augreg',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in1k',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in1k_384',
#  'convnext_large_mlp.clip_laion2b_augreg_ft_in12k_384',
#  'convnext_large_mlp.clip_laion2b_ft_320',
#  'convnext_large_mlp.clip_laion2b_ft_soup_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_384',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_320',
#  'convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_384',
#  'convnext_nano.d1h_in1k',
#  'convnext_nano.in12k',
#  'convnext_nano.in12k_ft_in1k',
#  'convnext_nano_ols.d1h_in1k',
#  'convnext_pico.d1_in1k',
#  'convnext_pico_ols.d1_in1k',
#  'convnext_small.fb_in1k',
#  'convnext_small.fb_in22k',
#  'convnext_small.fb_in22k_ft_in1k',
#  'convnext_small.fb_in22k_ft_in1k_384',
#  'convnext_small.in12k',
#  'convnext_small.in12k_ft_in1k',
#  'convnext_small.in12k_ft_in1k_384',
#  'convnext_tiny.fb_in1k',
#  'convnext_tiny.fb_in22k',
#  'convnext_tiny.fb_in22k_ft_in1k',
#  'convnext_tiny.fb_in22k_ft_in1k_384',
#  'convnext_tiny.in12k',
#  'convnext_tiny.in12k_ft_in1k',
#  'convnext_tiny.in12k_ft_in1k_384',
#  'convnext_tiny_hnf.a2h_in1k',
#  'convnext_xlarge.fb_in22k',
#  'convnext_xlarge.fb_in22k_ft_in1k',
#  'convnext_xlarge.fb_in22k_ft_in1k_384',
#  'convnext_xxlarge.clip_laion2b_rewind',
#  'convnext_xxlarge.clip_laion2b_soup',
#  'convnext_xxlarge.clip_laion2b_soup_ft_in1k',
#  'convnext_xxlarge.clip_laion2b_soup_ft_in12k',
#  'convnextv2_atto.fcmae',
#  'convnextv2_atto.fcmae_ft_in1k',
#  'convnextv2_base.fcmae',
#  'convnextv2_base.fcmae_ft_in1k',
#  'convnextv2_base.fcmae_ft_in22k_in1k',
#  'convnextv2_base.fcmae_ft_in22k_in1k_384',
#  'convnextv2_femto.fcmae',
#  'convnextv2_femto.fcmae_ft_in1k',
#  'convnextv2_huge.fcmae',
#  'convnextv2_huge.fcmae_ft_in1k',
#  'convnextv2_huge.fcmae_ft_in22k_in1k_384',
#  'convnextv2_huge.fcmae_ft_in22k_in1k_512',
#  'convnextv2_large.fcmae',
#  'convnextv2_large.fcmae_ft_in1k',
#  'convnextv2_large.fcmae_ft_in22k_in1k',
#  'convnextv2_large.fcmae_ft_in22k_in1k_384',
#  'convnextv2_nano.fcmae',
#  'convnextv2_nano.fcmae_ft_in1k',
#  'convnextv2_nano.fcmae_ft_in22k_in1k',
#  'convnextv2_nano.fcmae_ft_in22k_in1k_384',
#  'convnextv2_pico.fcmae',
#  'convnextv2_pico.fcmae_ft_in1k',
#  'convnextv2_tiny.fcmae',
#  'convnextv2_tiny.fcmae_ft_in1k',
#  'convnextv2_tiny.fcmae_ft_in22k_in1k',
#  'convnextv2_tiny.fcmae_ft_in22k_in1k_384',
#  'crossvit_9_240.in1k',
#  'crossvit_9_dagger_240.in1k',
#  'crossvit_15_240.in1k',
#  'crossvit_15_dagger_240.in1k',
#  'crossvit_15_dagger_408.in1k',
#  'crossvit_18_240.in1k',
#  'crossvit_18_dagger_240.in1k',
#  'crossvit_18_dagger_408.in1k',
#  'crossvit_base_240.in1k',
#  'crossvit_small_240.in1k',
#  'crossvit_tiny_240.in1k',
#  'cs3darknet_focus_l.c2ns_in1k',
#  'cs3darknet_focus_m.c2ns_in1k',
#  'cs3darknet_l.c2ns_in1k',
#  'cs3darknet_m.c2ns_in1k',
#  'cs3darknet_x.c2ns_in1k',
#  'cs3edgenet_x.c2_in1k',
#  'cs3se_edgenet_x.c2ns_in1k',
#  'cs3sedarknet_l.c2ns_in1k',
#  'cs3sedarknet_x.c2ns_in1k',
#  'cspdarknet53.ra_in1k',
#  'cspresnet50.ra_in1k',
#  'cspresnext50.ra_in1k',
#  'darknet53.c2ns_in1k',
#  'darknetaa53.c2ns_in1k',
#  'davit_base.msft_in1k',
#  'davit_base_fl.msft_florence2',
#  'davit_huge_fl.msft_florence2',
#  'davit_small.msft_in1k',
#  'davit_tiny.msft_in1k',
#  'deit3_base_patch16_224.fb_in1k',
#  'deit3_base_patch16_224.fb_in22k_ft_in1k',
#  'deit3_base_patch16_384.fb_in1k',
#  'deit3_base_patch16_384.fb_in22k_ft_in1k',
#  'deit3_huge_patch14_224.fb_in1k',
#  'deit3_huge_patch14_224.fb_in22k_ft_in1k',
#  'deit3_large_patch16_224.fb_in1k',
#  'deit3_large_patch16_224.fb_in22k_ft_in1k',
#  'deit3_large_patch16_384.fb_in1k',
#  'deit3_large_patch16_384.fb_in22k_ft_in1k',
#  'deit3_medium_patch16_224.fb_in1k',
#  'deit3_medium_patch16_224.fb_in22k_ft_in1k',
#  'deit3_small_patch16_224.fb_in1k',
#  'deit3_small_patch16_224.fb_in22k_ft_in1k',
#  'deit3_small_patch16_384.fb_in1k',
#  'deit3_small_patch16_384.fb_in22k_ft_in1k',
#  'deit_base_distilled_patch16_224.fb_in1k',
#  'deit_base_distilled_patch16_384.fb_in1k',
#  'deit_base_patch16_224.fb_in1k',
#  'deit_base_patch16_384.fb_in1k',
#  'deit_small_distilled_patch16_224.fb_in1k',
#  'deit_small_patch16_224.fb_in1k',
#  'deit_tiny_distilled_patch16_224.fb_in1k',
#  'deit_tiny_patch16_224.fb_in1k',
#  'densenet121.ra_in1k',
#  'densenet121.tv_in1k',
#  'densenet161.tv_in1k',
#  'densenet169.tv_in1k',
#  'densenet201.tv_in1k',
#  'densenetblur121d.ra_in1k',
#  'dla34.in1k',
#  'dla46_c.in1k',
#  'dla46x_c.in1k',
#  'dla60.in1k',
#  'dla60_res2net.in1k',
#  'dla60_res2next.in1k',
#  'dla60x.in1k',
#  'dla60x_c.in1k',
#  'dla102.in1k',
#  'dla102x2.in1k',
#  'dla102x.in1k',
#  'dla169.in1k',
#  'dm_nfnet_f0.dm_in1k',
#  'dm_nfnet_f1.dm_in1k',
#  'dm_nfnet_f2.dm_in1k',
#  'dm_nfnet_f3.dm_in1k',
#  'dm_nfnet_f4.dm_in1k',
#  'dm_nfnet_f5.dm_in1k',
#  'dm_nfnet_f6.dm_in1k',
#  'dpn68.mx_in1k',
#  'dpn68b.mx_in1k',
#  'dpn68b.ra_in1k',
#  'dpn92.mx_in1k',
#  'dpn98.mx_in1k',
#  'dpn107.mx_in1k',
#  'dpn131.mx_in1k',
#  'eca_botnext26ts_256.c1_in1k',
#  'eca_halonext26ts.c1_in1k',
#  'eca_nfnet_l0.ra2_in1k',
#  'eca_nfnet_l1.ra2_in1k',
#  'eca_nfnet_l2.ra3_in1k',
#  'eca_resnet33ts.ra2_in1k',
#  'eca_resnext26ts.ch_in1k',
#  'ecaresnet26t.ra2_in1k',
#  'ecaresnet50d.miil_in1k',
#  'ecaresnet50d_pruned.miil_in1k',
#  'ecaresnet50t.a1_in1k',
#  'ecaresnet50t.a2_in1k',
#  'ecaresnet50t.a3_in1k',
#  'ecaresnet50t.ra2_in1k',
#  'ecaresnet101d.miil_in1k',
#  'ecaresnet101d_pruned.miil_in1k',
#  'ecaresnet269d.ra2_in1k',
#  'ecaresnetlight.miil_in1k',
#  'edgenext_base.in21k_ft_in1k',
#  'edgenext_base.usi_in1k',
#  'edgenext_small.usi_in1k',
#  'edgenext_small_rw.sw_in1k',
#  'edgenext_x_small.in1k',
#  'edgenext_xx_small.in1k',
#  'efficientformer_l1.snap_dist_in1k',
#  'efficientformer_l3.snap_dist_in1k',
#  'efficientformer_l7.snap_dist_in1k',
#  'efficientformerv2_l.snap_dist_in1k',
#  'efficientformerv2_s0.snap_dist_in1k',
#  'efficientformerv2_s1.snap_dist_in1k',
#  'efficientformerv2_s2.snap_dist_in1k',
#  'efficientnet_b0.ra4_e3600_r224_in1k',
#  'efficientnet_b0.ra_in1k',
#  'efficientnet_b1.ft_in1k',
#  'efficientnet_b1.ra4_e3600_r240_in1k',
#  'efficientnet_b1_pruned.in1k',
#  'efficientnet_b2.ra_in1k',
#  'efficientnet_b2_pruned.in1k',
#  'efficientnet_b3.ra2_in1k',
#  'efficientnet_b3_pruned.in1k',
#  'efficientnet_b4.ra2_in1k',
#  'efficientnet_b5.sw_in12k',
#  'efficientnet_b5.sw_in12k_ft_in1k',
#  'efficientnet_el.ra_in1k',
#  'efficientnet_el_pruned.in1k',
#  'efficientnet_em.ra2_in1k',
#  'efficientnet_es.ra_in1k',
#  'efficientnet_es_pruned.in1k',
#  'efficientnet_lite0.ra_in1k',
#  'efficientnetv2_rw_m.agc_in1k',
#  'efficientnetv2_rw_s.ra2_in1k',
#  'efficientnetv2_rw_t.ra2_in1k',
#  'efficientvit_b0.r224_in1k',
#  'efficientvit_b1.r224_in1k',
#  'efficientvit_b1.r256_in1k',
#  'efficientvit_b1.r288_in1k',
#  'efficientvit_b2.r224_in1k',
#  'efficientvit_b2.r256_in1k',
#  'efficientvit_b2.r288_in1k',
#  'efficientvit_b3.r224_in1k',
#  'efficientvit_b3.r256_in1k',
#  'efficientvit_b3.r288_in1k',
#  'efficientvit_l1.r224_in1k',
#  'efficientvit_l2.r224_in1k',
#  'efficientvit_l2.r256_in1k',
#  'efficientvit_l2.r288_in1k',
#  'efficientvit_l2.r384_in1k',
#  'efficientvit_l3.r224_in1k',
#  'efficientvit_l3.r256_in1k',
#  'efficientvit_l3.r320_in1k',
#  'efficientvit_l3.r384_in1k',
#  'efficientvit_m0.r224_in1k',
#  'efficientvit_m1.r224_in1k',
#  'efficientvit_m2.r224_in1k',
#  'efficientvit_m3.r224_in1k',
#  'efficientvit_m4.r224_in1k',
#  'efficientvit_m5.r224_in1k',
#  'ese_vovnet19b_dw.ra_in1k',
#  'ese_vovnet39b.ra_in1k',
#  'eva02_base_patch14_224.mim_in22k',
#  'eva02_base_patch14_448.mim_in22k_ft_in1k',
#  'eva02_base_patch14_448.mim_in22k_ft_in22k',
#  'eva02_base_patch14_448.mim_in22k_ft_in22k_in1k',
#  'eva02_base_patch16_clip_224.merged2b',
#  'eva02_enormous_patch14_clip_224.laion2b',
#  'eva02_enormous_patch14_clip_224.laion2b_plus',
#  'eva02_large_patch14_224.mim_in22k',
#  'eva02_large_patch14_224.mim_m38m',
#  'eva02_large_patch14_448.mim_in22k_ft_in1k',
#  'eva02_large_patch14_448.mim_in22k_ft_in22k',
#  'eva02_large_patch14_448.mim_in22k_ft_in22k_in1k',
#  'eva02_large_patch14_448.mim_m38m_ft_in1k',
#  'eva02_large_patch14_448.mim_m38m_ft_in22k',
#  'eva02_large_patch14_448.mim_m38m_ft_in22k_in1k',
#  'eva02_large_patch14_clip_224.merged2b',
#  'eva02_large_patch14_clip_336.merged2b',
#  'eva02_small_patch14_224.mim_in22k',
#  'eva02_small_patch14_336.mim_in22k_ft_in1k',
#  'eva02_tiny_patch14_224.mim_in22k',
#  'eva02_tiny_patch14_336.mim_in22k_ft_in1k',
#  'eva_giant_patch14_224.clip_ft_in1k',
#  'eva_giant_patch14_336.clip_ft_in1k',
#  'eva_giant_patch14_336.m30m_ft_in22k_in1k',
#  'eva_giant_patch14_560.m30m_ft_in22k_in1k',
#  'eva_giant_patch14_clip_224.laion400m',
#  'eva_giant_patch14_clip_224.merged2b',
#  'eva_large_patch14_196.in22k_ft_in1k',
#  'eva_large_patch14_196.in22k_ft_in22k_in1k',
#  'eva_large_patch14_336.in22k_ft_in1k',
#  'eva_large_patch14_336.in22k_ft_in22k_in1k',
#  'fastvit_ma36.apple_dist_in1k',
#  'fastvit_ma36.apple_in1k',
#  'fastvit_mci0.apple_mclip',
#  'fastvit_mci1.apple_mclip',
#  'fastvit_mci2.apple_mclip',
#  'fastvit_s12.apple_dist_in1k',
#  'fastvit_s12.apple_in1k',
#  'fastvit_sa12.apple_dist_in1k',
#  'fastvit_sa12.apple_in1k',
#  'fastvit_sa24.apple_dist_in1k',
#  'fastvit_sa24.apple_in1k',
#  'fastvit_sa36.apple_dist_in1k',
#  'fastvit_sa36.apple_in1k',
#  'fastvit_t8.apple_dist_in1k',
#  'fastvit_t8.apple_in1k',
#  'fastvit_t12.apple_dist_in1k',
#  'fastvit_t12.apple_in1k',
#  'fbnetc_100.rmsp_in1k',
#  'fbnetv3_b.ra2_in1k',
#  'fbnetv3_d.ra2_in1k',
#  'fbnetv3_g.ra2_in1k',
#  'flexivit_base.300ep_in1k',
#  'flexivit_base.300ep_in21k',
#  'flexivit_base.600ep_in1k',
#  'flexivit_base.1000ep_in21k',
#  'flexivit_base.1200ep_in1k',
#  'flexivit_base.patch16_in21k',
#  'flexivit_base.patch30_in21k',
#  'flexivit_large.300ep_in1k',
#  'flexivit_large.600ep_in1k',
#  'flexivit_large.1200ep_in1k',
#  'flexivit_small.300ep_in1k',
#  'flexivit_small.600ep_in1k',
#  'flexivit_small.1200ep_in1k',
#  'focalnet_base_lrf.ms_in1k',
#  'focalnet_base_srf.ms_in1k',
#  'focalnet_huge_fl3.ms_in22k',
#  'focalnet_huge_fl4.ms_in22k',
#  'focalnet_large_fl3.ms_in22k',
#  'focalnet_large_fl4.ms_in22k',
#  'focalnet_small_lrf.ms_in1k',
#  'focalnet_small_srf.ms_in1k',
#  'focalnet_tiny_lrf.ms_in1k',
#  'focalnet_tiny_srf.ms_in1k',
#  'focalnet_xlarge_fl3.ms_in22k',
#  'focalnet_xlarge_fl4.ms_in22k',
#  'gc_efficientnetv2_rw_t.agc_in1k',
#  'gcresnet33ts.ra2_in1k',
#  'gcresnet50t.ra2_in1k',
#  'gcresnext26ts.ch_in1k',
#  'gcresnext50ts.ch_in1k',
#  'gcvit_base.in1k',
#  'gcvit_small.in1k',
#  'gcvit_tiny.in1k',
#  'gcvit_xtiny.in1k',
#  'gcvit_xxtiny.in1k',
#  'gernet_l.idstcv_in1k',
#  'gernet_m.idstcv_in1k',
#  'gernet_s.idstcv_in1k',
#  'ghostnet_100.in1k',
#  'ghostnetv2_100.in1k',
#  'ghostnetv2_130.in1k',
#  'ghostnetv2_160.in1k',
#  'gmixer_24_224.ra3_in1k',
#  'gmlp_s16_224.ra3_in1k',
#  'halo2botnet50ts_256.a1h_in1k',
#  'halonet26t.a1h_in1k',
#  'halonet50ts.a1h_in1k',
#  'haloregnetz_b.ra3_in1k',
#  'hardcorenas_a.miil_green_in1k',
#  'hardcorenas_b.miil_green_in1k',
#  'hardcorenas_c.miil_green_in1k',
#  'hardcorenas_d.miil_green_in1k',
#  'hardcorenas_e.miil_green_in1k',
#  'hardcorenas_f.miil_green_in1k',
#  'hgnet_base.ssld_in1k',
#  'hgnet_small.paddle_in1k',
#  'hgnet_small.ssld_in1k',
#  'hgnet_tiny.paddle_in1k',
#  'hgnet_tiny.ssld_in1k',
#  'hgnetv2_b0.ssld_stage1_in22k_in1k',
#  'hgnetv2_b0.ssld_stage2_ft_in1k',
#  'hgnetv2_b1.ssld_stage1_in22k_in1k',
#  'hgnetv2_b1.ssld_stage2_ft_in1k',
#  'hgnetv2_b2.ssld_stage1_in22k_in1k',
#  'hgnetv2_b2.ssld_stage2_ft_in1k',
#  'hgnetv2_b3.ssld_stage1_in22k_in1k',
#  'hgnetv2_b3.ssld_stage2_ft_in1k',
#  'hgnetv2_b4.ssld_stage1_in22k_in1k',
#  'hgnetv2_b4.ssld_stage2_ft_in1k',
#  'hgnetv2_b5.ssld_stage1_in22k_in1k',
#  'hgnetv2_b5.ssld_stage2_ft_in1k',
#  'hgnetv2_b6.ssld_stage1_in22k_in1k',
#  'hgnetv2_b6.ssld_stage2_ft_in1k',
#  'hiera_base_224.mae',
#  'hiera_base_224.mae_in1k_ft_in1k',
#  'hiera_base_plus_224.mae',
#  'hiera_base_plus_224.mae_in1k_ft_in1k',
#  'hiera_huge_224.mae',
#  'hiera_huge_224.mae_in1k_ft_in1k',
#  'hiera_large_224.mae',
#  'hiera_large_224.mae_in1k_ft_in1k',
#  'hiera_small_224.mae',
#  'hiera_small_224.mae_in1k_ft_in1k',
#  'hiera_small_abswin_256.sbb2_e200_in12k',
#  'hiera_small_abswin_256.sbb2_e200_in12k_ft_in1k',
#  'hiera_small_abswin_256.sbb2_pd_e200_in12k',
#  'hiera_small_abswin_256.sbb2_pd_e200_in12k_ft_in1k',
#  'hiera_tiny_224.mae',
#  'hiera_tiny_224.mae_in1k_ft_in1k',
#  'hrnet_w18.ms_aug_in1k',
#  'hrnet_w18.ms_in1k',
#  'hrnet_w18_small.gluon_in1k',
#  'hrnet_w18_small.ms_in1k',
#  'hrnet_w18_small_v2.gluon_in1k',
#  'hrnet_w18_small_v2.ms_in1k',
#  'hrnet_w18_ssld.paddle_in1k',
#  'hrnet_w30.ms_in1k',
#  'hrnet_w32.ms_in1k',
#  'hrnet_w40.ms_in1k',
#  'hrnet_w44.ms_in1k',
#  'hrnet_w48.ms_in1k',
#  'hrnet_w48_ssld.paddle_in1k',
#  'hrnet_w64.ms_in1k',
#  'inception_next_base.sail_in1k',
#  'inception_next_base.sail_in1k_384',
#  'inception_next_small.sail_in1k',
#  'inception_next_tiny.sail_in1k',
#  'inception_resnet_v2.tf_ens_adv_in1k',
#  'inception_resnet_v2.tf_in1k',
#  'inception_v3.gluon_in1k',
#  'inception_v3.tf_adv_in1k',
#  'inception_v3.tf_in1k',
#  'inception_v3.tv_in1k',
#  'inception_v4.tf_in1k',
#  'lambda_resnet26rpt_256.c1_in1k',
#  'lambda_resnet26t.c1_in1k',
#  'lambda_resnet50ts.a1h_in1k',
#  'lamhalobotnet50ts_256.a1h_in1k',
#  'lcnet_050.ra2_in1k',
#  'lcnet_075.ra2_in1k',
#  'lcnet_100.ra2_in1k',
#  'legacy_senet154.in1k',
#  'legacy_seresnet18.in1k',
#  'legacy_seresnet34.in1k',
#  'legacy_seresnet50.in1k',
#  'legacy_seresnet101.in1k',
#  'legacy_seresnet152.in1k',
#  'legacy_seresnext26_32x4d.in1k',
#  'legacy_seresnext50_32x4d.in1k',
#  'legacy_seresnext101_32x4d.in1k',
#  'legacy_xception.tf_in1k',
#  'levit_128.fb_dist_in1k',
#  'levit_128s.fb_dist_in1k',
#  'levit_192.fb_dist_in1k',
#  'levit_256.fb_dist_in1k',
#  'levit_384.fb_dist_in1k',
#  'levit_conv_128.fb_dist_in1k',
#  'levit_conv_128s.fb_dist_in1k',
#  'levit_conv_192.fb_dist_in1k',
#  'levit_conv_256.fb_dist_in1k',
#  'levit_conv_384.fb_dist_in1k',
#  'maxvit_base_tf_224.in1k',
#  'maxvit_base_tf_224.in21k',
#  'maxvit_base_tf_384.in1k',
#  'maxvit_base_tf_384.in21k_ft_in1k',
#  'maxvit_base_tf_512.in1k',
#  'maxvit_base_tf_512.in21k_ft_in1k',
#  'maxvit_large_tf_224.in1k',
#  'maxvit_large_tf_224.in21k',
#  'maxvit_large_tf_384.in1k',
#  'maxvit_large_tf_384.in21k_ft_in1k',
#  'maxvit_large_tf_512.in1k',
#  'maxvit_large_tf_512.in21k_ft_in1k',
#  'maxvit_nano_rw_256.sw_in1k',
#  'maxvit_rmlp_base_rw_224.sw_in12k',
#  'maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k',
#  'maxvit_rmlp_base_rw_384.sw_in12k_ft_in1k',
#  'maxvit_rmlp_nano_rw_256.sw_in1k',
#  'maxvit_rmlp_pico_rw_256.sw_in1k',
#  'maxvit_rmlp_small_rw_224.sw_in1k',
#  'maxvit_rmlp_tiny_rw_256.sw_in1k',
#  'maxvit_small_tf_224.in1k',
#  'maxvit_small_tf_384.in1k',
#  'maxvit_small_tf_512.in1k',
#  'maxvit_tiny_rw_224.sw_in1k',
#  'maxvit_tiny_tf_224.in1k',
#  'maxvit_tiny_tf_384.in1k',
#  'maxvit_tiny_tf_512.in1k',
#  'maxvit_xlarge_tf_224.in21k',
#  'maxvit_xlarge_tf_384.in21k_ft_in1k',
#  'maxvit_xlarge_tf_512.in21k_ft_in1k',
#  'maxxvit_rmlp_nano_rw_256.sw_in1k',
#  'maxxvit_rmlp_small_rw_256.sw_in1k',
#  'maxxvitv2_nano_rw_256.sw_in1k',
#  'maxxvitv2_rmlp_base_rw_224.sw_in12k',
#  'maxxvitv2_rmlp_base_rw_224.sw_in12k_ft_in1k',
#  'maxxvitv2_rmlp_base_rw_384.sw_in12k_ft_in1k',
#  'mixer_b16_224.goog_in21k',
#  'mixer_b16_224.goog_in21k_ft_in1k',
#  'mixer_b16_224.miil_in21k',
#  'mixer_b16_224.miil_in21k_ft_in1k',
#  'mixer_l16_224.goog_in21k',
#  'mixer_l16_224.goog_in21k_ft_in1k',
#  'mixnet_l.ft_in1k',
#  'mixnet_m.ft_in1k',
#  'mixnet_s.ft_in1k',
#  'mixnet_xl.ra_in1k',
#  'mnasnet_100.rmsp_in1k',
#  'mnasnet_small.lamb_in1k',
#  'mobilenet_edgetpu_v2_m.ra4_e3600_r224_in1k',
#  'mobilenetv1_100.ra4_e3600_r224_in1k',
#  'mobilenetv1_100h.ra4_e3600_r224_in1k',
#  'mobilenetv1_125.ra4_e3600_r224_in1k',
#  'mobilenetv2_050.lamb_in1k',
#  'mobilenetv2_100.ra_in1k',
#  'mobilenetv2_110d.ra_in1k',
#  'mobilenetv2_120d.ra_in1k',
#  'mobilenetv2_140.ra_in1k',
#  'mobilenetv3_large_100.miil_in21k',
#  'mobilenetv3_large_100.miil_in21k_ft_in1k',
#  'mobilenetv3_large_100.ra_in1k',
#  'mobilenetv3_rw.rmsp_in1k',
#  'mobilenetv3_small_050.lamb_in1k',
#  'mobilenetv3_small_075.lamb_in1k',
#  'mobilenetv3_small_100.lamb_in1k',
#  'mobilenetv4_conv_aa_large.e230_r384_in12k',
#  'mobilenetv4_conv_aa_large.e230_r384_in12k_ft_in1k',
#  'mobilenetv4_conv_aa_large.e230_r448_in12k_ft_in1k',
#  'mobilenetv4_conv_aa_large.e600_r384_in1k',
#  'mobilenetv4_conv_blur_medium.e500_r224_in1k',
#  'mobilenetv4_conv_large.e500_r256_in1k',
#  'mobilenetv4_conv_large.e600_r384_in1k',
#  'mobilenetv4_conv_medium.e500_r224_in1k',
#  'mobilenetv4_conv_medium.e500_r256_in1k',
#  'mobilenetv4_conv_small.e1200_r224_in1k',
#  'mobilenetv4_conv_small.e2400_r224_in1k',
#  'mobilenetv4_hybrid_large.e600_r384_in1k',
#  'mobilenetv4_hybrid_large.ix_e600_r384_in1k',
#  'mobilenetv4_hybrid_medium.e200_r256_in12k',
#  'mobilenetv4_hybrid_medium.e200_r256_in12k_ft_in1k',
#  'mobilenetv4_hybrid_medium.e500_r224_in1k',
#  'mobilenetv4_hybrid_medium.ix_e550_r256_in1k',
#  'mobilenetv4_hybrid_medium.ix_e550_r384_in1k',
#  'mobileone_s0.apple_in1k',
#  'mobileone_s1.apple_in1k',
#  'mobileone_s2.apple_in1k',
#  'mobileone_s3.apple_in1k',
#  'mobileone_s4.apple_in1k',
#  'mobilevit_s.cvnets_in1k',
#  'mobilevit_xs.cvnets_in1k',
#  'mobilevit_xxs.cvnets_in1k',
#  'mobilevitv2_050.cvnets_in1k',
#  'mobilevitv2_075.cvnets_in1k',
#  'mobilevitv2_100.cvnets_in1k',
#  'mobilevitv2_125.cvnets_in1k',
#  'mobilevitv2_150.cvnets_in1k',
#  'mobilevitv2_150.cvnets_in22k_ft_in1k',
#  'mobilevitv2_150.cvnets_in22k_ft_in1k_384',
#  'mobilevitv2_175.cvnets_in1k',
#  'mobilevitv2_175.cvnets_in22k_ft_in1k',
#  'mobilevitv2_175.cvnets_in22k_ft_in1k_384',
#  'mobilevitv2_200.cvnets_in1k',
#  'mobilevitv2_200.cvnets_in22k_ft_in1k',
#  'mobilevitv2_200.cvnets_in22k_ft_in1k_384',
#  'mvitv2_base.fb_in1k',
#  'mvitv2_base_cls.fb_inw21k',
#  'mvitv2_huge_cls.fb_inw21k',
#  'mvitv2_large.fb_in1k',
#  'mvitv2_large_cls.fb_inw21k',
#  'mvitv2_small.fb_in1k',
#  'mvitv2_tiny.fb_in1k',
#  'nasnetalarge.tf_in1k',
#  'nest_base_jx.goog_in1k',
#  'nest_small_jx.goog_in1k',
#  'nest_tiny_jx.goog_in1k',
#  'nextvit_base.bd_in1k',
#  'nextvit_base.bd_in1k_384',
#  'nextvit_base.bd_ssld_6m_in1k',
#  'nextvit_base.bd_ssld_6m_in1k_384',
#  'nextvit_large.bd_in1k',
#  'nextvit_large.bd_in1k_384',
#  'nextvit_large.bd_ssld_6m_in1k',
#  'nextvit_large.bd_ssld_6m_in1k_384',
#  'nextvit_small.bd_in1k',
#  'nextvit_small.bd_in1k_384',
#  'nextvit_small.bd_ssld_6m_in1k',
#  'nextvit_small.bd_ssld_6m_in1k_384',
#  'nf_regnet_b1.ra2_in1k',
#  'nf_resnet50.ra2_in1k',
#  'nfnet_l0.ra2_in1k',
#  'pit_b_224.in1k',
#  'pit_b_distilled_224.in1k',
#  'pit_s_224.in1k',
#  'pit_s_distilled_224.in1k',
#  'pit_ti_224.in1k',
#  'pit_ti_distilled_224.in1k',
#  'pit_xs_224.in1k',
#  'pit_xs_distilled_224.in1k',
#  'pnasnet5large.tf_in1k',
#  'poolformer_m36.sail_in1k',
#  'poolformer_m48.sail_in1k',
#  'poolformer_s12.sail_in1k',
#  'poolformer_s24.sail_in1k',
#  'poolformer_s36.sail_in1k',
#  'poolformerv2_m36.sail_in1k',
#  'poolformerv2_m48.sail_in1k',
#  'poolformerv2_s12.sail_in1k',
#  'poolformerv2_s24.sail_in1k',
#  'poolformerv2_s36.sail_in1k',
#  'pvt_v2_b0.in1k',
#  'pvt_v2_b1.in1k',
#  'pvt_v2_b2.in1k',
#  'pvt_v2_b2_li.in1k',
#  'pvt_v2_b3.in1k',
#  'pvt_v2_b4.in1k',
#  'pvt_v2_b5.in1k',
#  'rdnet_base.nv_in1k',
#  'rdnet_large.nv_in1k',
#  'rdnet_large.nv_in1k_ft_in1k_384',
#  'rdnet_small.nv_in1k',
#  'rdnet_tiny.nv_in1k',
#  'regnetv_040.ra3_in1k',
#  'regnetv_064.ra3_in1k',
#  'regnetx_002.pycls_in1k',
#  'regnetx_004.pycls_in1k',
#  'regnetx_004_tv.tv2_in1k',
#  'regnetx_006.pycls_in1k',
#  'regnetx_008.pycls_in1k',
#  'regnetx_008.tv2_in1k',
#  'regnetx_016.pycls_in1k',
#  'regnetx_016.tv2_in1k',
#  'regnetx_032.pycls_in1k',
#  'regnetx_032.tv2_in1k',
#  'regnetx_040.pycls_in1k',
#  'regnetx_064.pycls_in1k',
#  'regnetx_080.pycls_in1k',
#  'regnetx_080.tv2_in1k',
#  'regnetx_120.pycls_in1k',
#  'regnetx_160.pycls_in1k',
#  'regnetx_160.tv2_in1k',
#  'regnetx_320.pycls_in1k',
#  'regnetx_320.tv2_in1k',
#  'regnety_002.pycls_in1k',
#  'regnety_004.pycls_in1k',
#  'regnety_004.tv2_in1k',
#  'regnety_006.pycls_in1k',
#  'regnety_008.pycls_in1k',
#  'regnety_008_tv.tv2_in1k',
#  'regnety_016.pycls_in1k',
#  'regnety_016.tv2_in1k',
#  'regnety_032.pycls_in1k',
#  'regnety_032.ra_in1k',
#  'regnety_032.tv2_in1k',
#  'regnety_040.pycls_in1k',
#  'regnety_040.ra3_in1k',
#  'regnety_064.pycls_in1k',
#  'regnety_064.ra3_in1k',
#  'regnety_080.pycls_in1k',
#  'regnety_080.ra3_in1k',
#  'regnety_080_tv.tv2_in1k',
#  'regnety_120.pycls_in1k',
#  'regnety_120.sw_in12k',
#  'regnety_120.sw_in12k_ft_in1k',
#  'regnety_160.deit_in1k',
#  'regnety_160.lion_in12k_ft_in1k',
#  'regnety_160.pycls_in1k',
#  'regnety_160.sw_in12k',
#  'regnety_160.sw_in12k_ft_in1k',
#  'regnety_160.swag_ft_in1k',
#  'regnety_160.swag_lc_in1k',
#  'regnety_160.tv2_in1k',
#  'regnety_320.pycls_in1k',
#  'regnety_320.seer',
#  'regnety_320.seer_ft_in1k',
#  'regnety_320.swag_ft_in1k',
#  'regnety_320.swag_lc_in1k',
#  'regnety_320.tv2_in1k',
#  'regnety_640.seer',
#  'regnety_640.seer_ft_in1k',
#  'regnety_1280.seer',
#  'regnety_1280.seer_ft_in1k',
#  'regnety_1280.swag_ft_in1k',
#  'regnety_1280.swag_lc_in1k',
#  'regnety_2560.seer_ft_in1k',
#  'regnetz_040.ra3_in1k',
#  'regnetz_040_h.ra3_in1k',
#  'regnetz_b16.ra3_in1k',
#  'regnetz_c16.ra3_in1k',
#  'regnetz_c16_evos.ch_in1k',
#  'regnetz_d8.ra3_in1k',
#  'regnetz_d8_evos.ch_in1k',
#  'regnetz_d32.ra3_in1k',
#  'regnetz_e8.ra3_in1k',
#  'repghostnet_050.in1k',
#  'repghostnet_058.in1k',
#  'repghostnet_080.in1k',
#  'repghostnet_100.in1k',
#  'repghostnet_111.in1k',
#  'repghostnet_130.in1k',
#  'repghostnet_150.in1k',
#  'repghostnet_200.in1k',
#  'repvgg_a0.rvgg_in1k',
#  'repvgg_a1.rvgg_in1k',
#  'repvgg_a2.rvgg_in1k',
#  'repvgg_b0.rvgg_in1k',
#  'repvgg_b1.rvgg_in1k',
#  'repvgg_b1g4.rvgg_in1k',
#  'repvgg_b2.rvgg_in1k',
#  'repvgg_b2g4.rvgg_in1k',
#  'repvgg_b3.rvgg_in1k',
#  'repvgg_b3g4.rvgg_in1k',
#  'repvgg_d2se.rvgg_in1k',
#  'repvit_m0_9.dist_300e_in1k',
#  'repvit_m0_9.dist_450e_in1k',
#  'repvit_m1.dist_in1k',
#  'repvit_m1_0.dist_300e_in1k',
#  'repvit_m1_0.dist_450e_in1k',
#  'repvit_m1_1.dist_300e_in1k',
#  'repvit_m1_1.dist_450e_in1k',
#  'repvit_m1_5.dist_300e_in1k',
#  'repvit_m1_5.dist_450e_in1k',
#  'repvit_m2.dist_in1k',
#  'repvit_m2_3.dist_300e_in1k',
#  'repvit_m2_3.dist_450e_in1k',
#  'repvit_m3.dist_in1k',
#  'res2net50_14w_8s.in1k',
#  'res2net50_26w_4s.in1k',
#  'res2net50_26w_6s.in1k',
#  'res2net50_26w_8s.in1k',
#  'res2net50_48w_2s.in1k',
#  'res2net50d.in1k',
#  'res2net101_26w_4s.in1k',
#  'res2net101d.in1k',
#  'res2next50.in1k',
#  'resmlp_12_224.fb_dino',
#  'resmlp_12_224.fb_distilled_in1k',
#  'resmlp_12_224.fb_in1k',
#  'resmlp_24_224.fb_dino',
#  'resmlp_24_224.fb_distilled_in1k',
#  'resmlp_24_224.fb_in1k',
#  'resmlp_36_224.fb_distilled_in1k',
#  'resmlp_36_224.fb_in1k',
#  'resmlp_big_24_224.fb_distilled_in1k',
#  'resmlp_big_24_224.fb_in1k',
#  'resmlp_big_24_224.fb_in22k_ft_in1k',
#  'resnest14d.gluon_in1k',
#  'resnest26d.gluon_in1k',
#  'resnest50d.in1k',
#  'resnest50d_1s4x24d.in1k',
#  'resnest50d_4s2x40d.in1k',
#  'resnest101e.in1k',
#  'resnest200e.in1k',
#  'resnest269e.in1k',
#  'resnet10t.c3_in1k',
#  'resnet14t.c3_in1k',
#  'resnet18.a1_in1k',
#  'resnet18.a2_in1k',
#  'resnet18.a3_in1k',
#  'resnet18.fb_ssl_yfcc100m_ft_in1k',
#  'resnet18.fb_swsl_ig1b_ft_in1k',
#  'resnet18.gluon_in1k',
#  'resnet18.tv_in1k',
#  'resnet18d.ra2_in1k',
#  'resnet26.bt_in1k',
#  'resnet26d.bt_in1k',
#  'resnet26t.ra2_in1k',
#  'resnet32ts.ra2_in1k',
#  'resnet33ts.ra2_in1k',
#  'resnet34.a1_in1k',
#  'resnet34.a2_in1k',
#  'resnet34.a3_in1k',
#  'resnet34.bt_in1k',
#  'resnet34.gluon_in1k',
#  'resnet34.tv_in1k',
#  'resnet34d.ra2_in1k',
#  'resnet50.a1_in1k',
#  'resnet50.a1h_in1k',
#  'resnet50.a2_in1k',
#  'resnet50.a3_in1k',
#  'resnet50.am_in1k',
#  'resnet50.b1k_in1k',
#  'resnet50.b2k_in1k',
#  'resnet50.bt_in1k',
#  'resnet50.c1_in1k',
#  'resnet50.c2_in1k',
#  'resnet50.d_in1k',
#  'resnet50.fb_ssl_yfcc100m_ft_in1k',
#  'resnet50.fb_swsl_ig1b_ft_in1k',
#  'resnet50.gluon_in1k',
#  'resnet50.ra_in1k',
#  'resnet50.ram_in1k',
#  'resnet50.tv2_in1k',
#  'resnet50.tv_in1k',
#  'resnet50_clip.openai',
#  'resnet50_clip_gap.openai',
#  'resnet50_gn.a1h_in1k',
#  'resnet50c.gluon_in1k',
#  'resnet50d.a1_in1k',
#  'resnet50d.a2_in1k',
#  'resnet50d.a3_in1k',
#  'resnet50d.gluon_in1k',
#  'resnet50d.ra2_in1k',
#  'resnet50d.ra4_e3600_r224_in1k',
#  'resnet50s.gluon_in1k',
#  'resnet50x4_clip.openai',
#  'resnet50x4_clip_gap.openai',
#  'resnet50x16_clip.openai',
#  'resnet50x16_clip_gap.openai',
#  'resnet50x64_clip.openai',
#  'resnet50x64_clip_gap.openai',
#  'resnet51q.ra2_in1k',
#  'resnet61q.ra2_in1k',
#  'resnet101.a1_in1k',
#  'resnet101.a1h_in1k',
#  'resnet101.a2_in1k',
#  'resnet101.a3_in1k',
#  'resnet101.gluon_in1k',
#  'resnet101.tv2_in1k',
#  'resnet101.tv_in1k',
#  'resnet101_clip.openai',
#  'resnet101_clip_gap.openai',
#  'resnet101c.gluon_in1k',
#  'resnet101d.gluon_in1k',
#  'resnet101d.ra2_in1k',
#  'resnet101s.gluon_in1k',
#  'resnet152.a1_in1k',
#  'resnet152.a1h_in1k',
#  'resnet152.a2_in1k',
#  'resnet152.a3_in1k',
#  'resnet152.gluon_in1k',
#  'resnet152.tv2_in1k',
#  'resnet152.tv_in1k',
#  'resnet152c.gluon_in1k',
#  'resnet152d.gluon_in1k',
#  'resnet152d.ra2_in1k',
#  'resnet152s.gluon_in1k',
#  'resnet200d.ra2_in1k',
#  'resnetaa50.a1h_in1k',
#  'resnetaa50d.d_in12k',
#  'resnetaa50d.sw_in12k',
#  'resnetaa50d.sw_in12k_ft_in1k',
#  'resnetaa101d.sw_in12k',
#  'resnetaa101d.sw_in12k_ft_in1k',
#  'resnetblur50.bt_in1k',
#  'resnetrs50.tf_in1k',
#  'resnetrs101.tf_in1k',
#  'resnetrs152.tf_in1k',
#  'resnetrs200.tf_in1k',
#  'resnetrs270.tf_in1k',
#  'resnetrs350.tf_in1k',
#  'resnetrs420.tf_in1k',
#  'resnetv2_50.a1h_in1k',
#  'resnetv2_50d_evos.ah_in1k',
#  'resnetv2_50d_gn.ah_in1k',
#  'resnetv2_50x1_bit.goog_distilled_in1k',
#  'resnetv2_50x1_bit.goog_in21k',
#  'resnetv2_50x1_bit.goog_in21k_ft_in1k',
#  'resnetv2_50x3_bit.goog_in21k',
#  'resnetv2_50x3_bit.goog_in21k_ft_in1k',
#  'resnetv2_101.a1h_in1k',
#  'resnetv2_101x1_bit.goog_in21k',
#  'resnetv2_101x1_bit.goog_in21k_ft_in1k',
#  'resnetv2_101x3_bit.goog_in21k',
#  'resnetv2_101x3_bit.goog_in21k_ft_in1k',
#  'resnetv2_152x2_bit.goog_in21k',
#  'resnetv2_152x2_bit.goog_in21k_ft_in1k',
#  'resnetv2_152x2_bit.goog_teacher_in21k_ft_in1k',
#  'resnetv2_152x2_bit.goog_teacher_in21k_ft_in1k_384',
#  'resnetv2_152x4_bit.goog_in21k',
#  'resnetv2_152x4_bit.goog_in21k_ft_in1k',
#  'resnext26ts.ra2_in1k',
#  'resnext50_32x4d.a1_in1k',
#  'resnext50_32x4d.a1h_in1k',
#  'resnext50_32x4d.a2_in1k',
#  'resnext50_32x4d.a3_in1k',
#  'resnext50_32x4d.fb_ssl_yfcc100m_ft_in1k',
#  'resnext50_32x4d.fb_swsl_ig1b_ft_in1k',
#  'resnext50_32x4d.gluon_in1k',
#  'resnext50_32x4d.ra_in1k',
#  'resnext50_32x4d.tv2_in1k',
#  'resnext50_32x4d.tv_in1k',
#  'resnext50d_32x4d.bt_in1k',
#  'resnext101_32x4d.fb_ssl_yfcc100m_ft_in1k',
#  'resnext101_32x4d.fb_swsl_ig1b_ft_in1k',
#  'resnext101_32x4d.gluon_in1k',
#  'resnext101_32x8d.fb_ssl_yfcc100m_ft_in1k',
#  'resnext101_32x8d.fb_swsl_ig1b_ft_in1k',
#  'resnext101_32x8d.fb_wsl_ig1b_ft_in1k',
#  'resnext101_32x8d.tv2_in1k',
#  'resnext101_32x8d.tv_in1k',
#  'resnext101_32x16d.fb_ssl_yfcc100m_ft_in1k',
#  'resnext101_32x16d.fb_swsl_ig1b_ft_in1k',
#  'resnext101_32x16d.fb_wsl_ig1b_ft_in1k',
#  'resnext101_32x32d.fb_wsl_ig1b_ft_in1k',
#  'resnext101_64x4d.c1_in1k',
#  'resnext101_64x4d.gluon_in1k',
#  'resnext101_64x4d.tv_in1k',
#  'rexnet_100.nav_in1k',
#  'rexnet_130.nav_in1k',
#  'rexnet_150.nav_in1k',
#  'rexnet_200.nav_in1k',
#  'rexnet_300.nav_in1k',
#  'rexnetr_200.sw_in12k',
#  'rexnetr_200.sw_in12k_ft_in1k',
#  'rexnetr_300.sw_in12k',
#  'rexnetr_300.sw_in12k_ft_in1k',
#  'sam2_hiera_base_plus',
#  'sam2_hiera_large',
#  'sam2_hiera_small',
#  'sam2_hiera_tiny.r224',
#  'sam2_hiera_tiny.r896',
#  'samvit_base_patch16.sa1b',
#  'samvit_huge_patch16.sa1b',
#  'samvit_large_patch16.sa1b',
#  'sebotnet33ts_256.a1h_in1k',
#  'sehalonet33ts.ra2_in1k',
#  'selecsls42b.in1k',
#  'selecsls60.in1k',
#  'selecsls60b.in1k',
#  'semnasnet_075.rmsp_in1k',
#  'semnasnet_100.rmsp_in1k',
#  'senet154.gluon_in1k',
#  ...]

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/15 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00&lt;?]
#     </div>
# SuggestedLRs(valley=0.0005754399462603033)

# %%
# TODO
lr =   0.00057 # set optimal learning rate here
epochs = 10 # set number of one-cycles for training, try to experiment a bit

# %%
# TODO - you can change resnet18 to other architecture (same as above)
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(epochs, lr)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00&lt;?]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.691496</td>
#       <td>0.947415</td>
#       <td>0.338843</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.529808</td>
#       <td>0.560940</td>
#       <td>0.157025</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.306350</td>
#       <td>0.364361</td>
#       <td>0.123967</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.085404</td>
#       <td>0.294761</td>
#       <td>0.107438</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.911209</td>
#       <td>0.271296</td>
#       <td>0.090909</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.783956</td>
#       <td>0.255350</td>
#       <td>0.099174</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.690205</td>
#       <td>0.251498</td>
#       <td>0.099174</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.620482</td>
#       <td>0.246582</td>
#       <td>0.107438</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.566956</td>
#       <td>0.247308</td>
#       <td>0.107438</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.519605</td>
#       <td>0.246997</td>
#       <td>0.107438</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Evaluate the model's performance...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(8,8), dpi=80)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ...and see the misclassified images in the validation set.

# %%
interp.plot_top_losses(9, figsize=(13,13))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# If you see a mess, you might want to clean your data - there is a widget for that! It will list the most suspicios images (=highest loss) per set (train/valid) and category. Mark these images for deletion...

# %%
from fastai.vision.widgets import *

# TODO - repeatedly run this and following cell for each category and split (train/valid)
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('airplanes', 'cars', 'motorboat', 'motorcycles', 'trains'), value='airplanes'…

# %% [markdown]
# ...and now actually delete them.

# %%
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
print(len(cleaner.delete()))
# Out:
# 10

# %% [markdown]
# After deleting the images, you need to rerun the entire notebook from the first cell to update the dataloaders, as they will point to deleted files.

# %% [markdown]
# ## Test the model on a test set

# %%
# Create a test DataLoader
test_path = Path('./dataset') / 'test'
test_dl = learn.dls.test_dl(get_image_files(test_path))

# %%
# Get predictions
preds, targets = learn.get_preds(dl=test_dl)
pred_labels = torch.argmax(preds, dim=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# Get class names
class_names = learn.dls.vocab
# Convert predictions to class names
pred_class_names = [class_names[i] for i in pred_labels]
true_class_names = [Path(t).parent.name for t in test_dl.items]

# %%
from statistics import mean

print("Test error rate:")
print(1 - mean([actual == predicted for actual, predicted in zip(true_class_names, pred_class_names)]))
# Out:
# Test error rate:
# 0.20799999999999996

# %% [markdown]
# ## Let us save the model

# %%
learn.export('model.pkl')

# %% [markdown]
# Make sure to **download** `model.pkl` to your laptop, as you will need it later.
